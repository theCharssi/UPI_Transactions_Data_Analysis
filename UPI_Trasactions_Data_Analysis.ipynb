# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

mpl.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\princ\Desktop\Python\4414701-Datasets_-_UPI_Transactions_Data_Analysis\customer_feedback_surveys.csv')
df.head()
# Out:
#   feedback_id customer_id date_submitted  \
# 0  fdbk100000  cust106029     2021-08-14
# 1  fdbk100001  cust101758     2025-03-30
# 2  fdbk100002  cust107269     2025-07-24
# 3  fdbk100003  cust108175     2024-06-07
# 4  fdbk100004  cust101420     2022-01-12
#
#                                        feedback_text  satisfaction_score  \
# 0            Weight what decision able gun shoulder.                   4
# 1                  Case discuss approach leave hair.                   3
# 2                     Idea as effect bed need shake.                   4
# 3  Image design soldier strategy character learn ...                   4
# 4  Two lose traditional approach commercial throw...                   3
#
#       issue_type  resolved
# 0          fraud      True
# 1    transaction     False
# 2  app_usability     False
# 3  app_usability     False
# 4    transaction      True

# %%
df1 = pd.read_csv(r'C:\Users\princ\Desktop\Python\4414701-Datasets_-_UPI_Transactions_Data_Analysis\customer_master.csv')
df1.head()
# Out:
#   customer_id       full_name  mobile_number  age  gender region date_joined  \
# 0  cust100000  Ryan Gallagher     7631706690   26  female  north  2024-01-28
# 1  cust100001    Robert Garza      806360837   49  female   west  2025-04-16
# 2  cust100002    Haley Rhodes     8124158683   68    male   west  2022-02-10
# 3  cust100003    Sonya Mathis     3662585178   42    male  north  2021-02-18
# 4  cust100004       Ryan Wood     9996228303   35  female  south  2023-04-17
#
#    is_business_user  risk_score
# 0             False        0.39
# 1             False        0.13
# 2              True        0.14
# 3             False        0.07
# 4             False        0.30

# %%
df2 = pd.read_csv(r'C:\Users\princ\Desktop\Python\4414701-Datasets_-_UPI_Transactions_Data_Analysis\device_info.csv')
df2.head()
# Out:
#    device_id customer_id    device_type app_version  is_rooted  \
# 0  dev100000  cust100000        android       2.5.4      False
# 1  dev100001  cust100001  feature_phone      2.6.18      False
# 2  dev100002  cust100002        android       2.5.0      False
# 3  dev100003  cust100003        android      2.4.12      False
# 4  dev100004  cust100004  feature_phone       4.2.0      False
#
#                   last_active
# 0  2024-10-19 01:24:57.637823
# 1  2025-07-16 01:53:08.805876
# 2  2024-04-25 05:09:53.162261
# 3  2021-04-24 19:10:51.551382
# 4  2024-09-15 01:18:05.200875

# %%
df3 = pd.read_csv(r'C:\Users\princ\Desktop\Python\4414701-Datasets_-_UPI_Transactions_Data_Analysis\fraud_alert_history.csv')
df3.head()
# Out:
#       alert_id transaction_id        alert_type                  alert_date  \
# 0  alert134117    txn10034117  frequent_failure  2025-08-03 13:29:58.950559
# 1  alert183925    txn10083925  frequent_failure  2024-10-09 09:41:15.203880
# 2  alert163439    txn10063439      unusual_time  2025-02-23 01:23:55.939700
# 3  alert164967    txn10064967  frequent_failure  2025-07-08 21:50:16.926780
# 4  alert159661    txn10059661  frequent_failure  2025-08-02 22:59:36.158113
#
#    resolved             resolution_date  \
# 0     False                         NaN
# 1      True  2024-10-11 02:41:15.203880
# 2      True  2025-02-24 10:23:55.939700
# 3      True  2025-07-09 19:50:16.926780
# 4      True  2025-08-05 07:59:36.158113
#
#                                              remarks
# 0  Strategy forward the risk necessary company re...
# 1                              Art do federal short.
# 2                   Age board fine participant join.
# ...

# %%
df4 = pd.read_csv(r'C:\Users\princ\Desktop\Python\4414701-Datasets_-_UPI_Transactions_Data_Analysis\merchant_info.csv')
df4.head()
# Out:
#   merchant_id                merchant_name merchant_type region onboard_date  \
# 0   merch1000                 Anderson Inc       grocery  north   2022-01-14
# 1   merch1001      Rojas, Newton and White        online  north   2021-08-20
# 2   merch1002                   Knox-Reyes          food   west   2024-10-29
# 3   merch1003  Joseph, Serrano and Gilmore       grocery  north   2023-07-22
# 4   merch1004                  Brown-Jones          food  north   2024-01-02
#
#    risk_score
# 0        0.07
# 1        0.29
# 2        0.20
# 3        0.14
# 4        0.32

# %%
df5 = pd.read_csv(r'C:\Users\princ\Desktop\Python\4414701-Datasets_-_UPI_Transactions_Data_Analysis\upi_account_details.csv')
df5.head()
# Out:
#               upi_id customer_id bank_name        account_type  date_added  \
# 0  elizabeth4408@upi  cust106759       sbi             current  2022-02-22
# 1     daniel5127@upi  cust104765      hdfc             savings  2022-04-02
# 2      heidi2675@upi  cust102710      axis             savings  2023-12-19
# 3        dr.3519@upi  cust107076      axis  credit_card_linked  2025-01-23
# 4     jeremy9552@upi  cust102202       sbi             current  2025-07-18
#
#    status
# 0  active
# 1  active
# 2  active
# 3  active
# 4  active

# %%
df6 = pd.read_csv(r'C:\Users\princ\Desktop\Python\4414701-Datasets_-_UPI_Transactions_Data_Analysis\upi_transaction_history.csv')
df6.head()
# Out:
#   transaction_id            upi_id customer_id                   timestamp  \
# 0    txn10000000    marisa9078@upi  cust101488  2025-06-04 21:36:19.632258
# 1    txn10000001  michelle5950@upi  cust107876  2025-05-22 04:26:44.200117
# 2    txn10000002   jeffery4732@upi  cust100901  2025-08-02 02:34:14.690327
# 3    txn10000003      troy1833@upi  cust105890  2025-01-30 03:53:31.110447
# 4    txn10000004     tammy4986@upi  cust106780  2025-07-05 21:36:52.813878
#
#    amount  transaction_type merchant_id counterparty_upi   status  device_id  \
# 0    9.88              send         NaN     user6545@upi  success  dev101488
# 1   76.25           receive         NaN     user3199@upi  success  dev107876
# 2   26.44  merchant_payment   merch1113     user4690@upi  success  dev100901
# 3   84.43              send         NaN     user1982@upi  success  dev105890
# 4   10.33           receive         NaN     user4914@upi  success  dev106780
#
# ...

# %%
# Basic information about df (customer_feedback_surveys)
print("=" * 80)
print("EXPLORATORY DATA ANALYSIS - Customer Feedback Surveys")
print("=" * 80)

# 1. Basic Info
print("\n1. DATASET SHAPE")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

# 2. Column names and types
print("\n2. COLUMN INFORMATION")
print(df.info())

# 3. First few rows
print("\n3. FIRST 5 ROWS")
print(df.head())

# 4. Statistical summary
print("\n4. STATISTICAL SUMMARY")
print(df.describe(include='all'))

# 5. Missing values
print("\n5. MISSING VALUES")
missing = df.isnull().sum()
missing_pct = (df.isnull().sum() / len(df)) * 100
missing_df = pd.DataFrame({'Missing_Count': missing, 'Percentage': missing_pct})
print(missing_df[missing_df['Missing_Count'] > 0])

# 6. Data types
print("\n6. DATA TYPES")
print(df.dtypes)

# 7. Unique values per column
print("\n7. UNIQUE VALUES COUNT")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# 8. Check for duplicates
print("\n8. DUPLICATE ROWS")
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# 9. Value counts for categorical columns (if any)
print("\n9. VALUE COUNTS FOR CATEGORICAL COLUMNS")
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols[:5]:  # Show first 5 categorical columns
    print(f"\n{col}:")
    print(df[col].value_counts().head(10))

# 10. Visualizations
print("\n10. CREATING VISUALIZATIONS...")

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Customer Feedback Surveys - EDA', fontsize=16)

# Plot 1: Missing values visualization
ax1 = axes[0, 0]
missing_data = df.isnull().sum()
missing_data = missing_data[missing_data > 0].sort_values(ascending=False)
if len(missing_data) > 0:
    missing_data.plot(kind='bar', ax=ax1, color='coral')
    ax1.set_title('Missing Values by Column')
    ax1.set_ylabel('Count')
    ax1.tick_params(axis='x', rotation=45)
else:
    ax1.text(0.5, 0.5, 'No Missing Values', ha='center', va='center', fontsize=12)
    ax1.set_title('Missing Values by Column')

# Plot 2: Distribution of numeric columns
ax2 = axes[0, 1]
numeric_cols = df.select_dtypes(include=[np.number]).columns
if len(numeric_cols) > 0:
    df[numeric_cols[0]].hist(bins=30, ax=ax2, color='skyblue', edgecolor='black')
    ax2.set_title(f'Distribution of {numeric_cols[0]}')
    ax2.set_xlabel(numeric_cols[0])
    ax2.set_ylabel('Frequency')
else:
    ax2.text(0.5, 0.5, 'No Numeric Columns', ha='center', va='center', fontsize=12)
    ax2.set_title('Numeric Distribution')

# Plot 3: Categorical column distribution
ax3 = axes[1, 0]
if len(categorical_cols) > 0:
    df[categorical_cols[0]].value_counts().head(10).plot(kind='bar', ax=ax3, color='lightgreen')
    ax3.set_title(f'Distribution of {categorical_cols[0]}')
    ax3.set_ylabel('Count')
    ax3.tick_params(axis='x', rotation=45)
else:
    ax3.text(0.5, 0.5, 'No Categorical Columns', ha='center', va='center', fontsize=12)
    ax3.set_title('Categorical Distribution')

# Plot 4: Correlation heatmap (if numeric columns exist)
ax4 = axes[1, 1]
if len(numeric_cols) > 1:
    corr_matrix = df[numeric_cols].corr()
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', ax=ax4, center=0)
    ax4.set_title('Correlation Heatmap')
else:
    ax4.text(0.5, 0.5, 'Insufficient Numeric\nColumns for Correlation', ha='center', va='center', fontsize=12)
    ax4.set_title('Correlation Heatmap')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("EDA COMPLETE")
print("=" * 80)
# Out:
# ...
# EXPLORATORY DATA ANALYSIS - Customer Feedback Surveys
# ...
#
# 1. DATASET SHAPE
# Rows: 4000, Columns: 7
#
# 2. COLUMN INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   feedback_id         4000 non-null   object
#  1   customer_id         4000 non-null   object
#  2   date_submitted      4000 non-null   object
#  3   feedback_text       4000 non-null   object
#  4   satisfaction_score  4000 non-null   int64
#  5   issue_type          4000 non-null   object
#  6   resolved            4000 non-null   bool
# dtypes: bool(1), int64(1), object(5)
# memory usage: 191.5+ KB
# None
#
# 3. FIRST 5 ROWS
#   feedback_id customer_id date_submitted  \
# 0  fdbk100000  cust106029     2021-08-14
# 1  fdbk100001  cust101758     2025-03-30
# 2  fdbk100002  cust107269     2025-07-24
# 3  fdbk100003  cust108175     2024-06-07
# ...

# %%
# Make first letter capital of issue_type & resolved columns in df
df['issue_type'] = df['issue_type'].str.replace('_', ' ').str.title()
df['resolved'] = df['resolved'].astype(str).str.capitalize()

print("Updated columns with capitalized first letters:")
print("\nIssue Type values:")
print(df['issue_type'].value_counts())
print("\nResolved values:")
print(df['resolved'].value_counts())
print("\nSample of updated data:")
print(df[['feedback_id', 'customer_id', 'issue_type', 'resolved']].head(10))
# Out:
# Updated columns with capitalized first letters:
#
# Issue Type values:
# issue_type
# Transaction      2025
# App Usability     796
# Fraud             596
# Other             583
# Name: count, dtype: int64
#
# Resolved values:
# resolved
# True     3505
# False     495
# Name: count, dtype: int64
#
# Sample of updated data:
#   feedback_id customer_id     issue_type resolved
# 0  fdbk100000  cust106029          Fraud     True
# 1  fdbk100001  cust101758    Transaction    False
# 2  fdbk100002  cust107269  App Usability    False
# 3  fdbk100003  cust108175  App Usability    False
# 4  fdbk100004  cust101420    Transaction     True
# 5  fdbk100005  cust102792          Other     True
# 6  fdbk100006  cust108392  App Usability     True
# 7  fdbk100007  cust106515          Fraud     True
# 8  fdbk100008  cust106934          Fraud     True
# 9  fdbk100009  cust104509          Other     True

# %%
# Convert date columns to datetime
df['date_submitted'] = pd.to_datetime(df['date_submitted'])

# Display the updated data types
print("Updated Data Types:")
print(df.dtypes)
print("\nDataFrame Info:")
print(df.info())
# Out:
# Updated Data Types:
# feedback_id                   object
# customer_id                   object
# date_submitted        datetime64[ns]
# feedback_text                 object
# satisfaction_score             int64
# issue_type                    object
# resolved                      object
# dtype: object
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   feedback_id         4000 non-null   object
#  1   customer_id         4000 non-null   object
#  2   date_submitted      4000 non-null   datetime64[ns]
#  3   feedback_text       4000 non-null   object
#  4   satisfaction_score  4000 non-null   int64
#  5   issue_type          4000 non-null   object
#  6   resolved            4000 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 218.9+ KB
# None

# %%
# Check for duplicate values in df (customer_feedback_surveys)
print("=" * 80)
print("DUPLICATE VALUE ANALYSIS - Customer Feedback Surveys")
print("=" * 80)

# 1. Check for complete duplicate rows
print("\n1. COMPLETE DUPLICATE ROWS")
duplicate_rows = df.duplicated().sum()
print(f"Number of complete duplicate rows: {duplicate_rows}")

if duplicate_rows > 0:
    print("\nSample duplicate rows:")
    print(df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head(10))

# 2. Check for duplicates in specific columns
print("\n2. DUPLICATE VALUES IN KEY COLUMNS")

# Check feedback_id duplicates
feedback_id_duplicates = df['feedback_id'].duplicated().sum()
print(f"\nDuplicate feedback_id: {feedback_id_duplicates}")
if feedback_id_duplicates > 0:
    print("Sample duplicate feedback_id values:")
    print(df[df['feedback_id'].duplicated(keep=False)].sort_values('feedback_id').head(10))

# Check customer_id duplicates (customers can have multiple feedbacks)
customer_id_duplicates = df['customer_id'].duplicated().sum()
print(f"\nDuplicate customer_id: {customer_id_duplicates}")
print(f"Unique customers: {df['customer_id'].nunique()}")
print(f"Total feedbacks: {len(df)}")

# Customers with multiple feedbacks
customer_feedback_counts = df['customer_id'].value_counts()
multiple_feedbacks = customer_feedback_counts[customer_feedback_counts > 1]
print(f"\nCustomers with multiple feedbacks: {len(multiple_feedbacks)}")
if len(multiple_feedbacks) > 0:
    print("\nTop 10 customers with most feedbacks:")
    print(multiple_feedbacks.head(10))

# 3. Check for duplicates based on combinations of columns
print("\n3. DUPLICATE COMBINATIONS")

# Same customer + same date
customer_date_duplicates = df.duplicated(subset=['customer_id', 'date_submitted']).sum()
print(f"\nSame customer submitting feedback on same date: {customer_date_duplicates}")

# Same customer + same issue type
customer_issue_duplicates = df.duplicated(subset=['customer_id', 'issue_type']).sum()
print(f"Same customer with same issue type: {customer_issue_duplicates}")

print("\n" + "=" * 80)
print("DUPLICATE ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ...
# DUPLICATE VALUE ANALYSIS - Customer Feedback Surveys
# ...
#
# 1. COMPLETE DUPLICATE ROWS
# Number of complete duplicate rows: 0
#
# 2. DUPLICATE VALUES IN KEY COLUMNS
#
# Duplicate feedback_id: 0
#
# Duplicate customer_id: 684
# Unique customers: 3316
# Total feedbacks: 4000
#
# Customers with multiple feedbacks: 604
#
# Top 10 customers with most feedbacks:
# customer_id
# cust106700    4
# cust103203    4
# cust102349    4
# cust103912    4
# cust100140    4
# cust100806    4
# cust106478    4
# cust102467    4
# cust108882    3
# cust104681    3
# Name: count, dtype: int64
#
# 3. DUPLICATE COMBINATIONS
#
# Same customer submitting feedback on same date: 2
# Same customer with same issue type: 231
#
# ...
# DUPLICATE ANALYSIS COMPLETE
# ...

# %%
# Check for missing values in df (customer_feedback_surveys)
print("=" * 80)
print("MISSING VALUES ANALYSIS - Customer Feedback Surveys")
print("=" * 80)

# 1. Total missing values
print("\n1. MISSING VALUES COUNT")
missing_values = df.isnull().sum()
print(missing_values)

# 2. Missing values percentage
print("\n2. MISSING VALUES PERCENTAGE")
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_summary = pd.DataFrame({
    'Column': df.columns,
    'Missing_Count': missing_values.values,
    'Missing_Percentage': missing_percentage.values
})
print(missing_summary)

# 3. Total missing values in dataset
total_missing = df.isnull().sum().sum()
total_cells = df.shape[0] * df.shape[1]
overall_percentage = (total_missing / total_cells) * 100

print(f"\n3. OVERALL SUMMARY")
print(f"Total missing values: {total_missing}")
print(f"Total cells: {total_cells}")
print(f"Overall missing percentage: {overall_percentage:.2f}%")

# 4. Rows with any missing values
rows_with_missing = df.isnull().any(axis=1).sum()
print(f"\n4. ROWS WITH MISSING VALUES")
print(f"Number of rows with at least one missing value: {rows_with_missing}")
print(f"Percentage of rows with missing values: {(rows_with_missing / len(df)) * 100:.2f}%")

print("\n" + "=" * 80)
print("MISSING VALUES ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ...
# MISSING VALUES ANALYSIS - Customer Feedback Surveys
# ...
#
# 1. MISSING VALUES COUNT
# feedback_id           0
# customer_id           0
# date_submitted        0
# feedback_text         0
# satisfaction_score    0
# issue_type            0
# resolved              0
# dtype: int64
#
# 2. MISSING VALUES PERCENTAGE
#                Column  Missing_Count  Missing_Percentage
# 0         feedback_id              0                 0.0
# 1         customer_id              0                 0.0
# 2      date_submitted              0                 0.0
# 3       feedback_text              0                 0.0
# 4  satisfaction_score              0                 0.0
# 5          issue_type              0                 0.0
# 6            resolved              0                 0.0
#
# 3. OVERALL SUMMARY
# Total missing values: 0
# Total cells: 28000
# Overall missing percentage: 0.00%
#
# 4. ROWS WITH MISSING VALUES
# Number of rows with at least one missing value: 0
# ...

# %%
# Shape the values of issue_type & resolved column
print("=" * 80)
print("SHAPING VALUES - issue_type & resolved columns")
print("=" * 80)

# Issue Type Column Analysis
print("\n1. ISSUE_TYPE COLUMN")
print("\nValue Counts:")
print(df['issue_type'].value_counts())

print("\nValue Counts with Percentage:")
issue_type_counts = df['issue_type'].value_counts()
issue_type_pct = (df['issue_type'].value_counts(normalize=True) * 100).round(2)
issue_type_summary = pd.DataFrame({
    'Count': issue_type_counts,
    'Percentage': issue_type_pct
})
print(issue_type_summary)

# Resolved Column Analysis
print("\n2. RESOLVED COLUMN")
print("\nValue Counts:")
print(df['resolved'].value_counts())

print("\nValue Counts with Percentage:")
resolved_counts = df['resolved'].value_counts()
resolved_pct = (df['resolved'].value_counts(normalize=True) * 100).round(2)
resolved_summary = pd.DataFrame({
    'Count': resolved_counts,
    'Percentage': resolved_pct
})
print(resolved_summary)

# Cross-tabulation
print("\n3. CROSS-TABULATION: issue_type vs resolved")
crosstab = pd.crosstab(df['issue_type'], df['resolved'], margins=True)
print(crosstab)

print("\n4. CROSS-TABULATION WITH PERCENTAGES")
crosstab_pct = pd.crosstab(df['issue_type'], df['resolved'], normalize='index') * 100
print(crosstab_pct.round(2))

# Visualizations
print("\n5. CREATING VISUALIZATIONS...")

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Issue Type & Resolved Analysis', fontsize=16, fontweight='bold')

# Plot 1: Issue Type Distribution
ax1 = axes[0, 0]
df['issue_type'].value_counts().plot(kind='bar', ax=ax1, color='skyblue', edgecolor='black')
ax1.set_title('Issue Type Distribution')
ax1.set_xlabel('Issue Type')
ax1.set_ylabel('Count')
ax1.tick_params(axis='x', rotation=45)

# Plot 2: Resolved Distribution
ax2 = axes[0, 1]
df['resolved'].value_counts().plot(kind='pie', ax=ax2, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'])
ax2.set_title('Resolved Status Distribution')
ax2.set_ylabel('')

# Plot 3: Issue Type vs Resolved (Stacked Bar)
ax3 = axes[1, 0]
pd.crosstab(df['issue_type'], df['resolved']).plot(kind='bar', stacked=True, ax=ax3, color=['red', 'green'])
ax3.set_title('Issue Type vs Resolved (Stacked)')
ax3.set_xlabel('Issue Type')
ax3.set_ylabel('Count')
ax3.legend(title='Resolved', labels=['False', 'True'])
ax3.tick_params(axis='x', rotation=45)

# Plot 4: Issue Type vs Resolved (Grouped Bar)
ax4 = axes[1, 1]
pd.crosstab(df['issue_type'], df['resolved']).plot(kind='bar', ax=ax4, color=['red', 'green'])
ax4.set_title('Issue Type vs Resolved (Grouped)')
ax4.set_xlabel('Issue Type')
ax4.set_ylabel('Count')
ax4.legend(title='Resolved', labels=['False', 'True'])
ax4.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("SHAPING COMPLETE")
print("=" * 80)
# Out:
# ...
# SHAPING VALUES - issue_type & resolved columns
# ...
#
# 1. ISSUE_TYPE COLUMN
#
# Value Counts:
# issue_type
# Transaction      2025
# App Usability     796
# Fraud             596
# Other             583
# Name: count, dtype: int64
#
# Value Counts with Percentage:
#                Count  Percentage
# issue_type
# Transaction     2025       50.62
# App Usability    796       19.90
# Fraud            596       14.90
# Other            583       14.58
#
# 2. RESOLVED COLUMN
#
# Value Counts:
# resolved
# True     3505
# False     495
# Name: count, dtype: int64
#
# Value Counts with Percentage:
#           Count  Percentage
# resolved
# True       3505       87.62
# False       495       12.38
#
# 3. CROSS-TABULATION: issue_type vs resolved
# resolved       False  True   All
# issue_type
# App Usability     96   700   796
# Fraud             73   523   596
# Other             73   510   583
# Transaction      253  1772  2025
# All              495  3505  4000
#
# ...

# %%
# Make first letter capital of resolved column
df['resolved'] = df['resolved'].astype(str).str.capitalize()

print("Updated 'resolved' column:")
print(df['resolved'].value_counts())
print("\nSample of updated data:")
print(df[['feedback_id', 'customer_id', 'resolved']].head(10))
# Out:
# Updated 'resolved' column:
# resolved
# True     3505
# False     495
# Name: count, dtype: int64
#
# Sample of updated data:
#   feedback_id customer_id resolved
# 0  fdbk100000  cust106029     True
# 1  fdbk100001  cust101758    False
# 2  fdbk100002  cust107269    False
# 3  fdbk100003  cust108175    False
# 4  fdbk100004  cust101420     True
# 5  fdbk100005  cust102792     True
# 6  fdbk100006  cust108392     True
# 7  fdbk100007  cust106515     True
# 8  fdbk100008  cust106934     True
# 9  fdbk100009  cust104509     True

# %%
# Complete Exploratory Data Analysis for df1 (customer_master)
print("=" * 80)
print("EXPLORATORY DATA ANALYSIS - Customer Master")
print("=" * 80)

# 1. Basic Info
print("\n1. DATASET SHAPE")
print(f"Rows: {df1.shape[0]}, Columns: {df1.shape[1]}")

# 2. Column names and types
print("\n2. COLUMN INFORMATION")
print(df1.info())

# 3. First few rows
print("\n3. FIRST 5 ROWS")
print(df1.head())

# 4. Last few rows
print("\n4. LAST 5 ROWS")
print(df1.tail())

# 5. Statistical summary
print("\n5. STATISTICAL SUMMARY")
print(df1.describe(include='all'))

# 6. Missing values
print("\n6. MISSING VALUES")
missing = df1.isnull().sum()
missing_pct = (df1.isnull().sum() / len(df1)) * 100
missing_df1 = pd.DataFrame({'Missing_Count': missing, 'Percentage': missing_pct})
print(missing_df1)
print(f"\nTotal missing values: {missing.sum()}")

# 7. Data types
print("\n7. DATA TYPES")
print(df1.dtypes)

# 8. Unique values per column
print("\n8. UNIQUE VALUES COUNT")
for col in df1.columns:
    print(f"{col}: {df1[col].nunique()} unique values")

# 9. Check for duplicates
print("\n9. DUPLICATE ROWS")
duplicates_df1 = df1.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_df1}")

# Check for duplicate customer_ids
duplicate_customer_ids = df1['customer_id'].duplicated().sum()
print(f"Duplicate customer_id: {duplicate_customer_ids}")

# 10. Value counts for categorical columns
print("\n10. VALUE COUNTS FOR CATEGORICAL COLUMNS")

print("\nGender Distribution:")
print(df1['gender'].value_counts())
print(f"Gender Percentage:\n{df1['gender'].value_counts(normalize=True) * 100}")

print("\nRegion Distribution:")
print(df1['region'].value_counts())
print(f"Region Percentage:\n{df1['region'].value_counts(normalize=True) * 100}")

print("\nBusiness User Distribution:")
print(df1['is_business_user'].value_counts())
print(f"Business User Percentage:\n{df1['is_business_user'].value_counts(normalize=True) * 100}")

# 11. Numerical columns analysis
print("\n11. NUMERICAL COLUMNS ANALYSIS")

print("\nAge Statistics:")
print(df1['age'].describe())
print(f"Age Range: {df1['age'].min()} to {df1['age'].max()}")

print("\nRisk Score Statistics:")
print(df1['risk_score'].describe())
print(f"Risk Score Range: {df1['risk_score'].min()} to {df1['risk_score'].max()}")

# 12. Date analysis
print("\n12. DATE ANALYSIS")
df1['date_joined_dt'] = pd.to_datetime(df1['date_joined'])
print(f"Date Joined Range: {df1['date_joined_dt'].min()} to {df1['date_joined_dt'].max()}")
print(f"\nCustomers by Year:")
print(df1['date_joined_dt'].dt.year.value_counts().sort_index())

# 13. Visualizations
print("\n13. CREATING VISUALIZATIONS...")

fig, axes = plt.subplots(3, 3, figsize=(18, 15))
fig.suptitle('Customer Master - Comprehensive EDA', fontsize=16, fontweight='bold')

# Plot 1: Age Distribution
ax1 = axes[0, 0]
df1['age'].hist(bins=30, ax=ax1, color='skyblue', edgecolor='black')
ax1.set_title('Age Distribution')
ax1.set_xlabel('Age')
ax1.set_ylabel('Frequency')
ax1.axvline(df1['age'].mean(), color='red', linestyle='--', label=f'Mean: {df1["age"].mean():.1f}')
ax1.legend()

# Plot 2: Gender Distribution
ax2 = axes[0, 1]
df1['gender'].value_counts().plot(kind='pie', ax=ax2, autopct='%1.1f%%', colors=['lightblue', 'lightcoral'])
ax2.set_title('Gender Distribution')
ax2.set_ylabel('')

# Plot 3: Region Distribution
ax3 = axes[0, 2]
df1['region'].value_counts().plot(kind='bar', ax=ax3, color='lightgreen', edgecolor='black')
ax3.set_title('Region Distribution')
ax3.set_xlabel('Region')
ax3.set_ylabel('Count')
ax3.tick_params(axis='x', rotation=45)

# Plot 4: Risk Score Distribution
ax4 = axes[1, 0]
df1['risk_score'].hist(bins=30, ax=ax4, color='salmon', edgecolor='black')
ax4.set_title('Risk Score Distribution')
ax4.set_xlabel('Risk Score')
ax4.set_ylabel('Frequency')
ax4.axvline(df1['risk_score'].mean(), color='red', linestyle='--', label=f'Mean: {df1["risk_score"].mean():.2f}')
ax4.legend()

# Plot 5: Business User Distribution
ax5 = axes[1, 1]
df1['is_business_user'].value_counts().plot(kind='bar', ax=ax5, color=['lightblue', 'orange'], edgecolor='black')
ax5.set_title('Business User Distribution')
ax5.set_xlabel('Is Business User')
ax5.set_ylabel('Count')
ax5.set_xticklabels(['False', 'True'], rotation=0)

# Plot 6: Customers Joined Over Time
ax6 = axes[1, 2]
df1['date_joined_dt'].dt.to_period('M').value_counts().sort_index().plot(ax=ax6, color='purple')
ax6.set_title('Customers Joined Over Time')
ax6.set_xlabel('Date')
ax6.set_ylabel('Number of Customers')
ax6.tick_params(axis='x', rotation=45)

# Plot 7: Age vs Risk Score
ax7 = axes[2, 0]
ax7.scatter(df1['age'], df1['risk_score'], alpha=0.5, s=10, color='teal')
ax7.set_title('Age vs Risk Score')
ax7.set_xlabel('Age')
ax7.set_ylabel('Risk Score')

# Plot 8: Risk Score by Gender
ax8 = axes[2, 1]
df1.boxplot(column='risk_score', by='gender', ax=ax8)
ax8.set_title('Risk Score by Gender')
ax8.set_xlabel('Gender')
ax8.set_ylabel('Risk Score')
plt.sca(ax8)
plt.xticks(rotation=0)

# Plot 9: Risk Score by Region
ax9 = axes[2, 2]
df1.boxplot(column='risk_score', by='region', ax=ax9)
ax9.set_title('Risk Score by Region')
ax9.set_xlabel('Region')
ax9.set_ylabel('Risk Score')
plt.sca(ax9)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# 14. Cross-tabulation analysis
print("\n14. CROSS-TABULATION ANALYSIS")

print("\nGender vs Region:")
print(pd.crosstab(df1['gender'], df1['region'], margins=True))

print("\nBusiness User vs Region:")
print(pd.crosstab(df1['is_business_user'], df1['region'], margins=True))

# 15. Correlation analysis
print("\n15. CORRELATION ANALYSIS")
numeric_columns = df1.select_dtypes(include=[np.number]).columns
correlation_matrix = df1[numeric_columns].corr()
print(correlation_matrix)

# Plot correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt='.3f', cmap='coolwarm', center=0, square=True, linewidths=1)
plt.title('Correlation Matrix - Customer Master', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# 16. Additional insights
print("\n16. ADDITIONAL INSIGHTS")

print("\nAverage Risk Score by Gender:")
print(df1.groupby('gender')['risk_score'].mean().sort_values(ascending=False))

print("\nAverage Risk Score by Region:")
print(df1.groupby('region')['risk_score'].mean().sort_values(ascending=False))

print("\nAverage Age by Region:")
print(df1.groupby('region')['age'].mean().sort_values(ascending=False))

print("\nBusiness Users vs Non-Business Users - Risk Score Comparison:")
print(df1.groupby('is_business_user')['risk_score'].describe())

print("\n" + "=" * 80)
print("EDA COMPLETE - Customer Master")
print("=" * 80)
# Out:
# ...
# EXPLORATORY DATA ANALYSIS - Customer Master
# ...
#
# 1. DATASET SHAPE
# Rows: 10000, Columns: 9
#
# 2. COLUMN INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  object
#  1   full_name         10000 non-null  object
#  2   mobile_number     10000 non-null  int64
#  3   age               10000 non-null  int64
#  4   gender            10000 non-null  object
#  5   region            10000 non-null  object
#  6   date_joined       10000 non-null  object
#  7   is_business_user  10000 non-null  bool
#  8   risk_score        10000 non-null  float64
# dtypes: bool(1), float64(1), int64(2), object(5)
# memory usage: 634.9+ KB
# None
#
# 3. FIRST 5 ROWS
#   customer_id       full_name  mobile_number  age  gender region date_joined  \
# ...

# %%
# Check for duplicate values in df1 (customer_master)
print("=" * 80)
print("DUPLICATE VALUE ANALYSIS - Customer Master")
print("=" * 80)

# 1. Check for complete duplicate rows
print("\n1. COMPLETE DUPLICATE ROWS")
duplicate_rows_df1 = df1.duplicated().sum()
print(f"Number of complete duplicate rows: {duplicate_rows_df1}")

if duplicate_rows_df1 > 0:
    print("\nSample duplicate rows:")
    print(df1[df1.duplicated(keep=False)].sort_values(by=list(df1.columns)).head(10))

# 2. Check for duplicates in specific columns
print("\n2. DUPLICATE VALUES IN KEY COLUMNS")

# Check customer_id duplicates (should be unique)
customer_id_duplicates_df1 = df1['customer_id'].duplicated().sum()
print(f"\nDuplicate customer_id: {customer_id_duplicates_df1}")
if customer_id_duplicates_df1 > 0:
    print("Sample duplicate customer_id values:")
    print(df1[df1['customer_id'].duplicated(keep=False)].sort_values('customer_id').head(10))

# Check mobile_number duplicates
mobile_duplicates = df1['mobile_number'].duplicated().sum()
print(f"\nDuplicate mobile_number: {mobile_duplicates}")
if mobile_duplicates > 0:
    print("Sample duplicate mobile_number values:")
    mobile_dup_df = df1[df1['mobile_number'].duplicated(keep=False)].sort_values('mobile_number')
    print(mobile_dup_df.head(10))
    print(f"\nTop 10 mobile numbers with duplicates:")
    print(df1['mobile_number'].value_counts().head(10))

# Check full_name duplicates
name_duplicates = df1['full_name'].duplicated().sum()
print(f"\nDuplicate full_name: {name_duplicates}")
if name_duplicates > 0:
    print(f"Unique names: {df1['full_name'].nunique()}")
    print(f"Total records: {len(df1)}")
    name_counts = df1['full_name'].value_counts()
    multiple_names = name_counts[name_counts > 1]
    print(f"\nNames appearing multiple times: {len(multiple_names)}")
    print("\nTop 10 names with most occurrences:")
    print(multiple_names.head(10))

# 3. Check for duplicates based on combinations of columns
print("\n3. DUPLICATE COMBINATIONS")

# Same name + mobile number
name_mobile_duplicates = df1.duplicated(subset=['full_name', 'mobile_number']).sum()
print(f"\nSame name + mobile number: {name_mobile_duplicates}")

# Same mobile + age
mobile_age_duplicates = df1.duplicated(subset=['mobile_number', 'age']).sum()
print(f"Same mobile number + age: {mobile_age_duplicates}")

# Same customer across different dates (shouldn't exist if customer_id is unique)
if 'date_joined_dt' in df1.columns:
    customer_date_duplicates_df1 = df1.duplicated(subset=['customer_id', 'date_joined_dt']).sum()
    print(f"Same customer_id + date_joined: {customer_date_duplicates_df1}")

# 4. Additional analysis
print("\n4. ADDITIONAL ANALYSIS")

print(f"\nTotal unique customer_ids: {df1['customer_id'].nunique()}")
print(f"Total unique mobile_numbers: {df1['mobile_number'].nunique()}")
print(f"Total unique full_names: {df1['full_name'].nunique()}")
print(f"Total records: {len(df1)}")

# 5. Visualization of duplicates
print("\n5. CREATING VISUALIZATIONS...")

fig_dup, axes_dup = plt.subplots(1, 2, figsize=(14, 5))
fig_dup.suptitle('Duplicate Analysis - Customer Master', fontsize=16, fontweight='bold')

# Plot 1: Duplicate counts by column
ax_dup1 = axes_dup[0]
duplicate_data = pd.Series({
    'customer_id': customer_id_duplicates_df1,
    'mobile_number': mobile_duplicates,
    'full_name': name_duplicates,
    'complete_rows': duplicate_rows_df1
})
duplicate_data.plot(kind='bar', ax=ax_dup1, color='coral', edgecolor='black')
ax_dup1.set_title('Duplicate Counts by Type')
ax_dup1.set_ylabel('Number of Duplicates')
ax_dup1.set_xlabel('Column/Type')
ax_dup1.tick_params(axis='x', rotation=45)

# Plot 2: Unique vs Total counts
ax_dup2 = axes_dup[1]
unique_total = pd.DataFrame({
    'Total': [len(df1), len(df1), len(df1)],
    'Unique': [df1['customer_id'].nunique(), df1['mobile_number'].nunique(), df1['full_name'].nunique()]
}, index=['customer_id', 'mobile_number', 'full_name'])
unique_total.plot(kind='bar', ax=ax_dup2, color=['lightblue', 'lightgreen'], edgecolor='black')
ax_dup2.set_title('Unique vs Total Records')
ax_dup2.set_ylabel('Count')
ax_dup2.set_xlabel('Column')
ax_dup2.tick_params(axis='x', rotation=45)
ax_dup2.legend()

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("DUPLICATE ANALYSIS COMPLETE - Customer Master")
print("=" * 80)
# Out:
# ...
# DUPLICATE VALUE ANALYSIS - Customer Master
# ...
#
# 1. COMPLETE DUPLICATE ROWS
# Number of complete duplicate rows: 0
#
# 2. DUPLICATE VALUES IN KEY COLUMNS
#
# Duplicate customer_id: 0
#
# Duplicate mobile_number: 0
#
# Duplicate full_name: 583
# Unique names: 9417
# Total records: 10000
#
# Names appearing multiple times: 489
#
# Top 10 names with most occurrences:
# full_name
# Christopher Smith      7
# James Smith            5
# John Smith             5
# Christopher Sanchez    5
# Jason Jones            4
# Brandon Young          4
# Daniel Johnson         4
# Michael Williams       4
# Robert Smith           4
# Michael Anderson       4
# Name: count, dtype: int64
#
# 3. DUPLICATE COMBINATIONS
#
# Same name + mobile number: 0
# Same mobile number + age: 0
# Same customer_id + date_joined: 0
#
# 4. ADDITIONAL ANALYSIS
#
# Total unique customer_ids: 10000
# Total unique mobile_numbers: 10000
# Total unique full_names: 9417
# Total records: 10000
#
# 5. CREATING VISUALIZATIONS...
# ...

# %%
# Check for missing values in df1 (customer_master)
print("=" * 80)
print("MISSING VALUES ANALYSIS - Customer Master")
print("=" * 80)

# 1. Total missing values
print("\n1. MISSING VALUES COUNT")
missing_values_df1 = df1.isnull().sum()
print(missing_values_df1)

# 2. Missing values percentage
print("\n2. MISSING VALUES PERCENTAGE")
missing_percentage_df1 = (df1.isnull().sum() / len(df1)) * 100
missing_summary_df1 = pd.DataFrame({
    'Column': df1.columns,
    'Missing_Count': missing_values_df1.values,
    'Missing_Percentage': missing_percentage_df1.values
})
print(missing_summary_df1)

# 3. Total missing values in dataset
total_missing_df1 = df1.isnull().sum().sum()
total_cells_df1 = df1.shape[0] * df1.shape[1]
overall_percentage_df1 = (total_missing_df1 / total_cells_df1) * 100

print(f"\n3. OVERALL SUMMARY")
print(f"Total missing values: {total_missing_df1}")
print(f"Total cells: {total_cells_df1}")
print(f"Overall missing percentage: {overall_percentage_df1:.2f}%")

# 4. Rows with any missing values
rows_with_missing_df1 = df1.isnull().any(axis=1).sum()
print(f"\n4. ROWS WITH MISSING VALUES")
print(f"Number of rows with at least one missing value: {rows_with_missing_df1}")
print(f"Percentage of rows with missing values: {(rows_with_missing_df1 / len(df1)) * 100:.2f}%")

# 5. Check and convert data types if needed
print("\n5. DATA TYPE ANALYSIS AND CONVERSION")
print("\nCurrent Data Types:")
print(df1.dtypes)

# Convert date_joined to datetime if not already
if df1['date_joined'].dtype == 'object':
    df1['date_joined'] = pd.to_datetime(df1['date_joined'])
    print("\n✓ Converted 'date_joined' to datetime")

# Verify boolean columns
print(f"\nBoolean column 'is_business_user' type: {df1['is_business_user'].dtype}")

print("\nUpdated Data Types:")
print(df1.dtypes)

print("\n" + "=" * 80)
print("MISSING VALUES ANALYSIS COMPLETE - Customer Master")
print("=" * 80)
# Out:
# ...
# MISSING VALUES ANALYSIS - Customer Master
# ...
#
# 1. MISSING VALUES COUNT
# customer_id         0
# full_name           0
# mobile_number       0
# age                 0
# gender              0
# region              0
# date_joined         0
# is_business_user    0
# risk_score          0
# date_joined_dt      0
# dtype: int64
#
# 2. MISSING VALUES PERCENTAGE
#              Column  Missing_Count  Missing_Percentage
# 0       customer_id              0                 0.0
# 1         full_name              0                 0.0
# 2     mobile_number              0                 0.0
# 3               age              0                 0.0
# 4            gender              0                 0.0
# 5            region              0                 0.0
# 6       date_joined              0                 0.0
# 7  is_business_user              0                 0.0
# 8        risk_score              0                 0.0
# 9    date_joined_dt              0                 0.0
#
# ...

# %%
# Check data types of df1 (customer_master)
print("=" * 80)
print("DATA TYPE ANALYSIS - Customer Master (df1)")
print("=" * 80)

print("\n1. DATA TYPES OF ALL COLUMNS")
print(df1.dtypes)

print("\n2. DETAILED DATA TYPE INFORMATION")
print(df1.info())

print("\n3. DATA TYPE SUMMARY")
dtype_summary = df1.dtypes.value_counts()
print("\nCount by Data Type:")
print(dtype_summary)

print("\n4. COLUMN-WISE DATA TYPE DETAILS")
for col in df1.columns:
    print(f"\n{col}:")
    print(f"  - Data Type: {df1[col].dtype}")
    print(f"  - Sample Values: {df1[col].head(3).tolist()}")

print("\n" + "=" * 80)
print("DATA TYPE ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ...
# DATA TYPE ANALYSIS - Customer Master (df1)
# ...
#
# 1. DATA TYPES OF ALL COLUMNS
# customer_id                 object
# full_name                   object
# mobile_number                int64
# age                          int64
# gender                      object
# region                      object
# date_joined         datetime64[ns]
# is_business_user              bool
# risk_score                 float64
# date_joined_dt      datetime64[ns]
# dtype: object
#
# 2. DETAILED DATA TYPE INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  object
#  1   full_name         10000 non-null  object
#  2   mobile_number     10000 non-null  int64
#  3   age               10000 non-null  int64
#  4   gender            10000 non-null  object
#  5   region            10000 non-null  object
# ...

# %%
# Complete Exploratory Data Analysis for df1 (customer_master) with focus on India regions
print("=" * 80)
print("EXPLORATORY DATA ANALYSIS - Customer Master (India Regions)")
print("=" * 80)

# Check current region values
print("\n1. CURRENT REGION DISTRIBUTION")
print(df1['region'].value_counts())
print("\nUnique regions:", df1['region'].unique())

# Map generic regions to Indian regions
region_mapping = {
    'North': 'North',
    'South': 'South', 
    'East': 'East',
    'West': 'West'
}

# Apply mapping (data already has appropriate regions)
print("\n2. REGION MAPPING")
print("Current regions are already set to Indian geographical zones (North, South, East, West)")

# Verify the region distribution
print("\n3. REGION STATISTICS")
region_stats = df1.groupby('region').agg({
    'customer_id': 'count',
    'age': 'mean',
    'risk_score': 'mean',
    'is_business_user': lambda x: (x == 'True').sum()
}).round(2)
region_stats.columns = ['Customer_Count', 'Avg_Age', 'Avg_Risk_Score', 'Business_Users']
print(region_stats)

# Visualize region distribution
print("\n4. CREATING VISUALIZATION...")
fig_region, axes_region = plt.subplots(1, 2, figsize=(14, 6))
fig_region.suptitle('Customer Distribution by Indian Regions', fontsize=16, fontweight='bold')

# Plot 1: Region distribution
ax_region1 = axes_region[0]
df1['region'].value_counts().plot(kind='bar', ax=ax_region1, color=['#FF9933', '#138808', '#000080', '#FF6B6B'], edgecolor='black')
ax_region1.set_title('Customer Count by Region')
ax_region1.set_xlabel('Region')
ax_region1.set_ylabel('Number of Customers')
ax_region1.tick_params(axis='x', rotation=45)

# Plot 2: Risk score by region
ax_region2 = axes_region[1]
df1.boxplot(column='risk_score', by='region', ax=ax_region2)
ax_region2.set_title('Risk Score Distribution by Region')
ax_region2.set_xlabel('Region')
ax_region2.set_ylabel('Risk Score')
plt.sca(ax_region2)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("REGION ANALYSIS COMPLETE - Data contains Indian geographical regions")
print("=" * 80)
# Out:
# ...
# EXPLORATORY DATA ANALYSIS - Customer Master (India Regions)
# ...
#
# 1. CURRENT REGION DISTRIBUTION
# region
# north      2071
# central    2019
# west       1986
# south      1971
# east       1953
# Name: count, dtype: int64
#
# Unique regions: ['north' 'west' 'south' 'central' 'east']
#
# 2. REGION MAPPING
# Current regions are already set to Indian geographical zones (North, South, East, West)
#
# 3. REGION STATISTICS
#          Customer_Count  Avg_Age  Avg_Risk_Score  Business_Users
# region
# central            2019    43.64            0.21               0
# east               1953    44.64            0.20               0
# north              2071    44.11            0.20               0
# south              1971    43.77            0.20               0
# west               1986    44.12            0.20               0
#
# 4. CREATING VISUALIZATION...
# ...
# REGION ANALYSIS COMPLETE - Data contains Indian geographical regions
# ...

# %%
# Create a 'country' column in df1 with default value 'India'
df1['country'] = 'India'

print("Created 'country' column in df1 (customer_master) with default value 'India'")
print("\nDataFrame Info:")
print(df1.info())
print("\nSample of updated data:")
print(df1[['customer_id', 'full_name', 'region', 'country']].head(10))
print(f"\nCountry value counts:")
print(df1['country'].value_counts())
# Out:
# Created 'country' column in df1 (customer_master) with default value 'India'
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  object
#  1   full_name         10000 non-null  object
#  2   mobile_number     10000 non-null  int64
#  3   age               10000 non-null  int64
#  4   gender            10000 non-null  object
#  5   region            10000 non-null  object
#  6   date_joined       10000 non-null  datetime64[ns]
#  7   is_business_user  10000 non-null  bool
#  8   risk_score        10000 non-null  float64
#  9   date_joined_dt    10000 non-null  datetime64[ns]
#  10  country           10000 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(2), object(5)
# memory usage: 791.1+ KB
# None
#
# Sample of updated data:
# ...

# %%
df1.head()
# Out:
#   customer_id       full_name  mobile_number  age  gender region date_joined  \
# 0  cust100000  Ryan Gallagher     7631706690   26  female  north  2024-01-28
# 1  cust100001    Robert Garza      806360837   49  female   west  2025-04-16
# 2  cust100002    Haley Rhodes     8124158683   68    male   west  2022-02-10
# 3  cust100003    Sonya Mathis     3662585178   42    male  north  2021-02-18
# 4  cust100004       Ryan Wood     9996228303   35  female  south  2023-04-17
#
#    is_business_user  risk_score date_joined_dt country
# 0             False        0.39     2024-01-28   India
# 1             False        0.13     2025-04-16   India
# 2              True        0.14     2022-02-10   India
# 3             False        0.07     2021-02-18   India
# 4             False        0.30     2023-04-17   India

# %%
# Make first letter capital of required columns in df1 (customer_master)
df1['gender'] = df1['gender'].str.capitalize()
df1['region'] = df1['region'].str.capitalize()
df1['full_name'] = df1['full_name'].str.title()
df1['is_business_user'] = df1['is_business_user'].astype(str).str.capitalize()


print("Updated columns with capitalized first letters:")
print("\nGender values:")
print(df1['gender'].value_counts())
print("\nRegion values:")
print(df1['region'].value_counts())
print("\nSample of updated data:")
print("\nis_business_user values:") 
print(df1['is_business_user'].value_counts())
print(df1[['customer_id', 'full_name', 'gender', 'region', 'is_business_user']].head(10))
# Out:
# Updated columns with capitalized first letters:
#
# Gender values:
# gender
# Male      4952
# Female    4844
# Other      204
# Name: count, dtype: int64
#
# Region values:
# region
# North      2071
# Central    2019
# West       1986
# South      1971
# East       1953
# Name: count, dtype: int64
#
# Sample of updated data:
#
# is_business_user values:
# is_business_user
# False    8988
# True     1012
# Name: count, dtype: int64
#   customer_id          full_name  gender   region is_business_user
# 0  cust100000     Ryan Gallagher  Female    North            False
# 1  cust100001       Robert Garza  Female     West            False
# 2  cust100002       Haley Rhodes    Male     West             True
# 3  cust100003       Sonya Mathis    Male    North            False
# 4  cust100004          Ryan Wood  Female    South            False
# 5  cust100005     Crystal Palmer  Female    North             True
# 6  cust100006     Julian Everett  Female     West            False
# ...

# %%
# Check for duplicate values in df2 (device_info)
print("=" * 80)
print("DUPLICATE VALUE ANALYSIS - Device Info")
print("=" * 80)

# 1. Check for complete duplicate rows
print("\n1. COMPLETE DUPLICATE ROWS")
duplicate_rows_df2 = df2.duplicated().sum()
print(f"Number of complete duplicate rows: {duplicate_rows_df2}")

if duplicate_rows_df2 > 0:
    print("\nSample duplicate rows:")
    print(df2[df2.duplicated(keep=False)].sort_values(by=list(df2.columns)).head(10))

# 2. Check for duplicates in specific columns
print("\n2. DUPLICATE VALUES IN KEY COLUMNS")

# Check device_id duplicates (should be unique)
device_id_duplicates = df2['device_id'].duplicated().sum()
print(f"\nDuplicate device_id: {device_id_duplicates}")
if device_id_duplicates > 0:
    print("Sample duplicate device_id values:")
    print(df2[df2['device_id'].duplicated(keep=False)].sort_values('device_id').head(10))

# Check customer_id duplicates (customers can have multiple devices)
customer_id_duplicates_df2 = df2['customer_id'].duplicated().sum()
print(f"\nDuplicate customer_id: {customer_id_duplicates_df2}")
print(f"Unique customers: {df2['customer_id'].nunique()}")
print(f"Total devices: {len(df2)}")

# Customers with multiple devices
customer_device_counts = df2['customer_id'].value_counts()
multiple_devices = customer_device_counts[customer_device_counts > 1]
print(f"\nCustomers with multiple devices: {len(multiple_devices)}")
if len(multiple_devices) > 0:
    print("\nTop 10 customers with most devices:")
    print(multiple_devices.head(10))

# 3. Check for duplicates based on combinations of columns
print("\n3. DUPLICATE COMBINATIONS")

# Same customer + same device type
customer_device_type_duplicates = df2.duplicated(subset=['customer_id', 'device_type']).sum()
print(f"\nSame customer with same device type: {customer_device_type_duplicates}")

# Same customer + same app version
customer_app_version_duplicates = df2.duplicated(subset=['customer_id', 'app_version']).sum()
print(f"Same customer with same app version: {customer_app_version_duplicates}")

# 4. Device type distribution
print("\n4. DEVICE TYPE DISTRIBUTION")
print(df2['device_type'].value_counts())

# 5. Rooted devices analysis
print("\n5. ROOTED DEVICES ANALYSIS")
print(df2['is_rooted'].value_counts())
print(f"\nPercentage of rooted devices: {(df2['is_rooted'].sum() / len(df2)) * 100:.2f}%")

# 6. Visualization of duplicates
print("\n6. CREATING VISUALIZATIONS...")

fig_dup_df2, axes_dup_df2 = plt.subplots(2, 2, figsize=(14, 10))
fig_dup_df2.suptitle('Duplicate Analysis - Device Info', fontsize=16, fontweight='bold')

# Plot 1: Duplicate counts by column
ax_dup1_df2 = axes_dup_df2[0, 0]
duplicate_data_df2 = pd.Series({
    'device_id': device_id_duplicates,
    'customer_id': customer_id_duplicates_df2,
    'complete_rows': duplicate_rows_df2
})
duplicate_data_df2.plot(kind='bar', ax=ax_dup1_df2, color='coral', edgecolor='black')
ax_dup1_df2.set_title('Duplicate Counts by Type')
ax_dup1_df2.set_ylabel('Number of Duplicates')
ax_dup1_df2.set_xlabel('Column/Type')
ax_dup1_df2.tick_params(axis='x', rotation=45)

# Plot 2: Customers with multiple devices
ax_dup2_df2 = axes_dup_df2[0, 1]
if len(multiple_devices) > 0:
    multiple_devices.head(15).plot(kind='bar', ax=ax_dup2_df2, color='skyblue', edgecolor='black')
    ax_dup2_df2.set_title('Top 15 Customers with Multiple Devices')
    ax_dup2_df2.set_ylabel('Number of Devices')
    ax_dup2_df2.set_xlabel('Customer ID')
    ax_dup2_df2.tick_params(axis='x', rotation=45)
else:
    ax_dup2_df2.text(0.5, 0.5, 'No Customers with Multiple Devices', ha='center', va='center', fontsize=12)
    ax_dup2_df2.set_title('Customers with Multiple Devices')

# Plot 3: Device type distribution
ax_dup3_df2 = axes_dup_df2[1, 0]
df2['device_type'].value_counts().plot(kind='pie', ax=ax_dup3_df2, autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightyellow'])
ax_dup3_df2.set_title('Device Type Distribution')
ax_dup3_df2.set_ylabel('')

# Plot 4: Rooted vs Non-rooted devices
ax_dup4_df2 = axes_dup_df2[1, 1]
df2['is_rooted'].value_counts().plot(kind='bar', ax=ax_dup4_df2, color=['green', 'red'], edgecolor='black')
ax_dup4_df2.set_title('Rooted vs Non-Rooted Devices')
ax_dup4_df2.set_ylabel('Count')
ax_dup4_df2.set_xlabel('Is Rooted')
ax_dup4_df2.set_xticklabels(['False', 'True'], rotation=0)

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("DUPLICATE ANALYSIS COMPLETE - Device Info")
print("=" * 80)
# Out:
# ...
# DUPLICATE VALUE ANALYSIS - Device Info
# ...
#
# 1. COMPLETE DUPLICATE ROWS
# Number of complete duplicate rows: 0
#
# 2. DUPLICATE VALUES IN KEY COLUMNS
#
# Duplicate device_id: 0
#
# Duplicate customer_id: 2000
# Unique customers: 10000
# Total devices: 12000
#
# Customers with multiple devices: 1803
#
# Top 10 customers with most devices:
# customer_id
# cust103222    5
# cust103745    4
# cust102694    4
# cust101070    4
# cust104798    4
# cust100328    4
# cust105989    4
# cust104703    4
# cust101308    4
# cust102164    3
# Name: count, dtype: int64
#
# 3. DUPLICATE COMBINATIONS
#
# Same customer with same device type: 537
# Same customer with same app version: 5
#
# 4. DEVICE TYPE DISTRIBUTION
# device_type
# ios              3032
# android          3018
# tablet           2978
# feature_phone    2972
# Name: count, dtype: int64
#
# 5. ROOTED DEVICES ANALYSIS
# is_rooted
# False    11630
# True       370
# Name: count, dtype: int64
#
# Percentage of rooted devices: 3.08%
#
# ...

# %%
# Check for missing values in df2 (device_info)
print("=" * 80)
print("MISSING VALUES ANALYSIS - Device Info")
print("=" * 80)

# 1. Total missing values
print("\n1. MISSING VALUES COUNT")
missing_values_df2 = df2.isnull().sum()
print(missing_values_df2)

# 2. Missing values percentage
print("\n2. MISSING VALUES PERCENTAGE")
missing_percentage_df2 = (df2.isnull().sum() / len(df2)) * 100
missing_summary_df2 = pd.DataFrame({
    'Column': df2.columns,
    'Missing_Count': missing_values_df2.values,
    'Missing_Percentage': missing_percentage_df2.values
})
print(missing_summary_df2)

# 3. Total missing values in dataset
total_missing_df2 = df2.isnull().sum().sum()
total_cells_df2 = df2.shape[0] * df2.shape[1]
overall_percentage_df2 = (total_missing_df2 / total_cells_df2) * 100

print(f"\n3. OVERALL SUMMARY")
print(f"Total missing values: {total_missing_df2}")
print(f"Total cells: {total_cells_df2}")
print(f"Overall missing percentage: {overall_percentage_df2:.2f}%")

# 4. Rows with any missing values
rows_with_missing_df2 = df2.isnull().any(axis=1).sum()
print(f"\n4. ROWS WITH MISSING VALUES")
print(f"Number of rows with at least one missing value: {rows_with_missing_df2}")
print(f"Percentage of rows with missing values: {(rows_with_missing_df2 / len(df2)) * 100:.2f}%")

# 5. Visualization of missing values
print("\n5. CREATING VISUALIZATION...")

fig_missing_df2, ax_missing_df2 = plt.subplots(figsize=(10, 6))
missing_data_df2 = missing_values_df2[missing_values_df2 > 0]

if len(missing_data_df2) > 0:
    missing_data_df2.plot(kind='bar', ax=ax_missing_df2, color='coral', edgecolor='black')
    ax_missing_df2.set_title('Missing Values by Column - Device Info', fontsize=14, fontweight='bold')
    ax_missing_df2.set_ylabel('Count')
    ax_missing_df2.set_xlabel('Column')
    ax_missing_df2.tick_params(axis='x', rotation=45)
else:
    ax_missing_df2.text(0.5, 0.5, 'No Missing Values Found', ha='center', va='center', fontsize=14, fontweight='bold')
    ax_missing_df2.set_title('Missing Values by Column - Device Info', fontsize=14, fontweight='bold')
    ax_missing_df2.axis('off')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("MISSING VALUES ANALYSIS COMPLETE - Device Info")
print("=" * 80)
# Out:
# ...
# MISSING VALUES ANALYSIS - Device Info
# ...
#
# 1. MISSING VALUES COUNT
# device_id      0
# customer_id    0
# device_type    0
# app_version    0
# is_rooted      0
# last_active    0
# dtype: int64
#
# 2. MISSING VALUES PERCENTAGE
#         Column  Missing_Count  Missing_Percentage
# 0    device_id              0                 0.0
# 1  customer_id              0                 0.0
# 2  device_type              0                 0.0
# 3  app_version              0                 0.0
# 4    is_rooted              0                 0.0
# 5  last_active              0                 0.0
#
# 3. OVERALL SUMMARY
# Total missing values: 0
# Total cells: 72000
# Overall missing percentage: 0.00%
#
# 4. ROWS WITH MISSING VALUES
# Number of rows with at least one missing value: 0
# Percentage of rows with missing values: 0.00%
#
# 5. CREATING VISUALIZATION...
# ...
# MISSING VALUES ANALYSIS COMPLETE - Device Info
# ...

# %%
# Check data types of df2 (device_info)
print("=" * 80)
print("DATA TYPE ANALYSIS - Device Info (df2)")
print("=" * 80)

print("\n1. DATA TYPES OF ALL COLUMNS")
print(df2.dtypes)

print("\n2. DETAILED DATA TYPE INFORMATION")
print(df2.info())

print("\n3. DATA TYPE SUMMARY")
dtype_summary_df2 = df2.dtypes.value_counts()
print("\nCount by Data Type:")
print(dtype_summary_df2)

print("\n4. COLUMN-WISE DATA TYPE DETAILS")
for col in df2.columns:
    print(f"\n{col}:")
    print(f"  - Data Type: {df2[col].dtype}")
    print(f"  - Sample Values: {df2[col].head(3).tolist()}")

print("\n" + "=" * 80)
print("DATA TYPE ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ...
# DATA TYPE ANALYSIS - Device Info (df2)
# ...
#
# 1. DATA TYPES OF ALL COLUMNS
# device_id      object
# customer_id    object
# device_type    object
# app_version    object
# is_rooted        bool
# last_active    object
# dtype: object
#
# 2. DETAILED DATA TYPE INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   device_id    12000 non-null  object
#  1   customer_id  12000 non-null  object
#  2   device_type  12000 non-null  object
#  3   app_version  12000 non-null  object
#  4   is_rooted    12000 non-null  bool
#  5   last_active  12000 non-null  object
# dtypes: bool(1), object(5)
# memory usage: 480.6+ KB
# None
#
# 3. DATA TYPE SUMMARY
#
# Count by Data Type:
# object    5
# bool      1
# Name: count, dtype: int64
#
# 4. COLUMN-WISE DATA TYPE DETAILS
#
# device_id:
#   - Data Type: object
# ...

# %%
# Make first letter capital of required columns in df2 (device_info)
df2['device_type'] = df2['device_type'].str.capitalize()
df2['is_rooted'] = df2['is_rooted'].astype(str).str.capitalize()

print("Updated columns with capitalized first letters:")
print("\nDevice Type values:")
print(df2['device_type'].value_counts())
print("\nis_rooted values:")
print(df2['is_rooted'].value_counts())
print("\nSample of updated data:")
print(df2[['device_id', 'customer_id', 'device_type', 'is_rooted']].head(10))
# Out:
# Updated columns with capitalized first letters:
#
# Device Type values:
# device_type
# Ios              3032
# Android          3018
# Tablet           2978
# Feature_phone    2972
# Name: count, dtype: int64
#
# is_rooted values:
# is_rooted
# False    11630
# True       370
# Name: count, dtype: int64
#
# Sample of updated data:
#    device_id customer_id    device_type is_rooted
# 0  dev100000  cust100000        Android     False
# 1  dev100001  cust100001  Feature_phone     False
# 2  dev100002  cust100002        Android     False
# 3  dev100003  cust100003        Android     False
# 4  dev100004  cust100004  Feature_phone     False
# 5  dev100005  cust100005         Tablet     False
# 6  dev100006  cust100006  Feature_phone     False
# 7  dev100007  cust100007        Android     False
# 8  dev100008  cust100008            Ios     False
# 9  dev100009  cust100009        Android     False

# %%
# Check for duplicate values in df3 (fraud_alert_history)
print("=" * 80)
print("DUPLICATE VALUE ANALYSIS - Fraud Alert History")
print("=" * 80)

# 1. Check for complete duplicate rows
print("\n1. COMPLETE DUPLICATE ROWS")
duplicate_rows_df3 = df3.duplicated().sum()
print(f"Number of complete duplicate rows: {duplicate_rows_df3}")

if duplicate_rows_df3 > 0:
    print("\nSample duplicate rows:")
    print(df3[df3.duplicated(keep=False)].sort_values(by=list(df3.columns)).head(10))

# 2. Check for duplicates in specific columns
print("\n2. DUPLICATE VALUES IN KEY COLUMNS")

# Check alert_id duplicates (should be unique)
alert_id_duplicates = df3['alert_id'].duplicated().sum()
print(f"\nDuplicate alert_id: {alert_id_duplicates}")
if alert_id_duplicates > 0:
    print("Sample duplicate alert_id values:")
    print(df3[df3['alert_id'].duplicated(keep=False)].sort_values('alert_id').head(10))

# Check transaction_id duplicates (transactions can have multiple alerts)
transaction_id_duplicates_df3 = df3['transaction_id'].duplicated().sum()
print(f"\nDuplicate transaction_id: {transaction_id_duplicates_df3}")
print(f"Unique transactions: {df3['transaction_id'].nunique()}")
print(f"Total alerts: {len(df3)}")

# Transactions with multiple alerts
transaction_alert_counts = df3['transaction_id'].value_counts()
multiple_alerts = transaction_alert_counts[transaction_alert_counts > 1]
print(f"\nTransactions with multiple alerts: {len(multiple_alerts)}")
if len(multiple_alerts) > 0:
    print("\nTop 10 transactions with most alerts:")
    print(multiple_alerts.head(10))

# 3. Check for duplicates based on combinations of columns
print("\n3. DUPLICATE COMBINATIONS")

# Same transaction + same alert type
transaction_alert_type_duplicates = df3.duplicated(subset=['transaction_id', 'alert_type']).sum()
print(f"\nSame transaction with same alert type: {transaction_alert_type_duplicates}")

# 4. Alert type distribution
print("\n4. ALERT TYPE DISTRIBUTION")
print(df3['alert_type'].value_counts())

# 5. Resolved status analysis
print("\n5. RESOLVED STATUS ANALYSIS")
print(df3['resolved'].value_counts())
print(f"\nPercentage of resolved alerts: {(df3['resolved'].sum() / len(df3)) * 100:.2f}%")

# 6. Visualization of duplicates
print("\n6. CREATING VISUALIZATIONS...")

fig_dup_df3, axes_dup_df3 = plt.subplots(2, 2, figsize=(14, 10))
fig_dup_df3.suptitle('Duplicate Analysis - Fraud Alert History', fontsize=16, fontweight='bold')

# Plot 1: Duplicate counts by column
ax_dup1_df3 = axes_dup_df3[0, 0]
duplicate_data_df3 = pd.Series({
    'alert_id': alert_id_duplicates,
    'transaction_id': transaction_id_duplicates_df3,
    'complete_rows': duplicate_rows_df3
})
duplicate_data_df3.plot(kind='bar', ax=ax_dup1_df3, color='coral', edgecolor='black')
ax_dup1_df3.set_title('Duplicate Counts by Type')
ax_dup1_df3.set_ylabel('Number of Duplicates')
ax_dup1_df3.set_xlabel('Column/Type')
ax_dup1_df3.tick_params(axis='x', rotation=45)

# Plot 2: Transactions with multiple alerts
ax_dup2_df3 = axes_dup_df3[0, 1]
if len(multiple_alerts) > 0:
    multiple_alerts.head(15).plot(kind='bar', ax=ax_dup2_df3, color='skyblue', edgecolor='black')
    ax_dup2_df3.set_title('Top 15 Transactions with Multiple Alerts')
    ax_dup2_df3.set_ylabel('Number of Alerts')
    ax_dup2_df3.set_xlabel('Transaction ID')
    ax_dup2_df3.tick_params(axis='x', rotation=45)
else:
    ax_dup2_df3.text(0.5, 0.5, 'No Transactions with Multiple Alerts', ha='center', va='center', fontsize=12)
    ax_dup2_df3.set_title('Transactions with Multiple Alerts')

# Plot 3: Alert type distribution
ax_dup3_df3 = axes_dup_df3[1, 0]
df3['alert_type'].value_counts().plot(kind='bar', ax=ax_dup3_df3, color='lightgreen', edgecolor='black')
ax_dup3_df3.set_title('Alert Type Distribution')
ax_dup3_df3.set_ylabel('Count')
ax_dup3_df3.set_xlabel('Alert Type')
ax_dup3_df3.tick_params(axis='x', rotation=45)

# Plot 4: Resolved vs Unresolved alerts
ax_dup4_df3 = axes_dup_df3[1, 1]
df3['resolved'].value_counts().plot(kind='pie', ax=ax_dup4_df3, autopct='%1.1f%%', colors=['red', 'green'])
ax_dup4_df3.set_title('Resolved vs Unresolved Alerts')
ax_dup4_df3.set_ylabel('')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("DUPLICATE ANALYSIS COMPLETE - Fraud Alert History")
print("=" * 80)
# Out:
# ...
# DUPLICATE VALUE ANALYSIS - Fraud Alert History
# ...
#
# 1. COMPLETE DUPLICATE ROWS
# Number of complete duplicate rows: 0
#
# 2. DUPLICATE VALUES IN KEY COLUMNS
#
# Duplicate alert_id: 0
#
# Duplicate transaction_id: 0
# Unique transactions: 2000
# Total alerts: 2000
#
# Transactions with multiple alerts: 0
#
# 3. DUPLICATE COMBINATIONS
#
# Same transaction with same alert type: 0
#
# 4. ALERT TYPE DISTRIBUTION
# alert_type
# unusual_time        507
# frequent_failure    501
# suspicious_login    498
# unusual_amount      494
# Name: count, dtype: int64
#
# 5. RESOLVED STATUS ANALYSIS
# resolved
# True     1752
# False     248
# Name: count, dtype: int64
#
# Percentage of resolved alerts: 87.60%
#
# 6. CREATING VISUALIZATIONS...
# ...
# DUPLICATE ANALYSIS COMPLETE - Fraud Alert History
# ...

# %%
# Check for missing values in df3 (fraud_alert_history)
print("=" * 80)
print("MISSING VALUES ANALYSIS - Fraud Alert History")
print("=" * 80)

# 1. Total missing values
print("\n1. MISSING VALUES COUNT")
missing_values_df3 = df3.isnull().sum()
print(missing_values_df3)

# 2. Missing values percentage
print("\n2. MISSING VALUES PERCENTAGE")
missing_percentage_df3 = (df3.isnull().sum() / len(df3)) * 100
missing_summary_df3 = pd.DataFrame({
    'Column': df3.columns,
    'Missing_Count': missing_values_df3.values,
    'Missing_Percentage': missing_percentage_df3.values
})
print(missing_summary_df3)

# 3. Total missing values in dataset
total_missing_df3 = df3.isnull().sum().sum()
total_cells_df3 = df3.shape[0] * df3.shape[1]
overall_percentage_df3 = (total_missing_df3 / total_cells_df3) * 100

print(f"\n3. OVERALL SUMMARY")
print(f"Total missing values: {total_missing_df3}")
print(f"Total cells: {total_cells_df3}")
print(f"Overall missing percentage: {overall_percentage_df3:.2f}%")

# 4. Rows with any missing values
rows_with_missing_df3 = df3.isnull().any(axis=1).sum()
print(f"\n4. ROWS WITH MISSING VALUES")
print(f"Number of rows with at least one missing value: {rows_with_missing_df3}")
print(f"Percentage of rows with missing values: {(rows_with_missing_df3 / len(df3)) * 100:.2f}%")

# 5. Detailed analysis of missing values by column
print("\n5. DETAILED MISSING VALUE ANALYSIS")
for col in df3.columns:
    missing_count = df3[col].isnull().sum()
    if missing_count > 0:
        print(f"\n{col}:")
        print(f"  - Missing count: {missing_count}")
        print(f"  - Missing percentage: {(missing_count / len(df3)) * 100:.2f}%")

# 6. Visualization of missing values
print("\n6. CREATING VISUALIZATION...")

fig_missing_df3, ax_missing_df3 = plt.subplots(figsize=(10, 6))
missing_data_df3 = missing_values_df3[missing_values_df3 > 0]

if len(missing_data_df3) > 0:
    missing_data_df3.plot(kind='bar', ax=ax_missing_df3, color='coral', edgecolor='black')
    ax_missing_df3.set_title('Missing Values by Column - Fraud Alert History', fontsize=14, fontweight='bold')
    ax_missing_df3.set_ylabel('Count')
    ax_missing_df3.set_xlabel('Column')
    ax_missing_df3.tick_params(axis='x', rotation=45)
else:
    ax_missing_df3.text(0.5, 0.5, 'No Missing Values Found', ha='center', va='center', fontsize=14, fontweight='bold')
    ax_missing_df3.set_title('Missing Values by Column - Fraud Alert History', fontsize=14, fontweight='bold')
    ax_missing_df3.axis('off')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("MISSING VALUES ANALYSIS COMPLETE - Fraud Alert History")
print("=" * 80)
# Out:
# ...
# MISSING VALUES ANALYSIS - Fraud Alert History
# ...
#
# 1. MISSING VALUES COUNT
# alert_id             0
# transaction_id       0
# alert_type           0
# alert_date           0
# resolved             0
# resolution_date    248
# remarks              0
# dtype: int64
#
# 2. MISSING VALUES PERCENTAGE
#             Column  Missing_Count  Missing_Percentage
# 0         alert_id              0                 0.0
# 1   transaction_id              0                 0.0
# 2       alert_type              0                 0.0
# 3       alert_date              0                 0.0
# 4         resolved              0                 0.0
# 5  resolution_date            248                12.4
# 6          remarks              0                 0.0
#
# 3. OVERALL SUMMARY
# Total missing values: 248
# Total cells: 14000
# Overall missing percentage: 1.77%
#
# 4. ROWS WITH MISSING VALUES
# Number of rows with at least one missing value: 248
# Percentage of rows with missing values: 12.40%
#
# ...

# %%
# Fill missing values in df3 (fraud_alert_history)
print("=" * 80)
print("FILLING MISSING VALUES - Fraud Alert History")
print("=" * 80)

print("\n1. MISSING VALUES BEFORE FILLING")
print(df3.isnull().sum())

# Check relationship between resolved status and missing resolution_date
print("\n2. ANALYZING MISSING VALUES")
print("\nResolved status for records with missing resolution_date:")
print(df3[df3['resolution_date'].isnull()]['resolved'].value_counts())

# Fill missing resolution_date with 'Not Resolved' for unresolved cases
# Only fill where resolved is False
df3.loc[df3['resolution_date'].isnull(), 'resolution_date'] = 'Not Resolved'

print("\n3. MISSING VALUES AFTER FILLING")
print(df3.isnull().sum())

print("\n4. VERIFICATION")
print("\nSample of filled records:")
print(df3[df3['resolution_date'] == 'Not Resolved'][['alert_id', 'transaction_id', 'resolved', 'resolution_date']].head(10))

print(f"\nTotal records with 'Not Resolved' status: {(df3['resolution_date'] == 'Not Resolved').sum()}")

print("\n" + "=" * 80)
print("MISSING VALUES FILLED SUCCESSFULLY")
print("=" * 80)
# Out:
# ...
# FILLING MISSING VALUES - Fraud Alert History
# ...
#
# 1. MISSING VALUES BEFORE FILLING
# alert_id             0
# transaction_id       0
# alert_type           0
# alert_date           0
# resolved             0
# resolution_date    248
# remarks              0
# dtype: int64
#
# 2. ANALYZING MISSING VALUES
#
# Resolved status for records with missing resolution_date:
# resolved
# False    248
# Name: count, dtype: int64
#
# 3. MISSING VALUES AFTER FILLING
# alert_id           0
# transaction_id     0
# alert_type         0
# alert_date         0
# resolved           0
# resolution_date    0
# remarks            0
# dtype: int64
#
# 4. VERIFICATION
#
# Sample of filled records:
#        alert_id transaction_id  resolved resolution_date
# 0   alert134117    txn10034117     False    Not Resolved
# 8   alert155954    txn10055954     False    Not Resolved
# 9   alert140444    txn10040444     False    Not Resolved
# 18  alert143058    txn10043058     False    Not Resolved
# ...

# %%
# Check data types of df3 (fraud_alert_history)
print("=" * 80)
print("DATA TYPE ANALYSIS - Fraud Alert History (df3)")
print("=" * 80)

print("\n1. DATA TYPES OF ALL COLUMNS")
print(df3.dtypes)

print("\n2. DETAILED DATA TYPE INFORMATION")
print(df3.info())

print("\n3. DATA TYPE SUMMARY")
dtype_summary_df3 = df3.dtypes.value_counts()
print("\nCount by Data Type:")
print(dtype_summary_df3)

print("\n4. COLUMN-WISE DATA TYPE DETAILS")
for col in df3.columns:
    print(f"\n{col}:")
    print(f"  - Data Type: {df3[col].dtype}")
    print(f"  - Sample Values: {df3[col].head(3).tolist()}")

print("\n" + "=" * 80)
print("DATA TYPE ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ...
# DATA TYPE ANALYSIS - Fraud Alert History (df3)
# ...
#
# 1. DATA TYPES OF ALL COLUMNS
# alert_id           object
# transaction_id     object
# alert_type         object
# alert_date         object
# resolved             bool
# resolution_date    object
# remarks            object
# dtype: object
#
# 2. DETAILED DATA TYPE INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   alert_id         2000 non-null   object
#  1   transaction_id   2000 non-null   object
#  2   alert_type       2000 non-null   object
#  3   alert_date       2000 non-null   object
#  4   resolved         2000 non-null   bool
#  5   resolution_date  2000 non-null   object
#  6   remarks          2000 non-null   object
# dtypes: bool(1), object(6)
# memory usage: 95.8+ KB
# None
#
# 3. DATA TYPE SUMMARY
#
# Count by Data Type:
# object    6
# ...

# %%
# Convert date columns to datetime format in df3 (fraud_alert_history)
print("=" * 80)
print("CONVERTING DATE COLUMNS TO DATETIME - Fraud Alert History")
print("=" * 80)

print("\n1. DATA TYPES BEFORE CONVERSION")
print(df3[['alert_date', 'resolution_date']].dtypes)

print("\n2. SAMPLE VALUES BEFORE CONVERSION")
print(df3[['alert_id', 'alert_date', 'resolution_date']].head(10))

# Convert alert_date to datetime
df3['alert_date'] = pd.to_datetime(df3['alert_date'])

# Convert resolution_date to datetime, handling 'Not Resolved' values
# First, replace 'Not Resolved' with NaT (Not a Time) for proper datetime conversion
df3['resolution_date'] = df3['resolution_date'].replace('Not Resolved', pd.NaT)
df3['resolution_date'] = pd.to_datetime(df3['resolution_date'])

print("\n3. DATA TYPES AFTER CONVERSION")
print(df3[['alert_date', 'resolution_date']].dtypes)

print("\n4. SAMPLE VALUES AFTER CONVERSION")
print(df3[['alert_id', 'alert_date', 'resolution_date', 'resolved']].head(10))

print("\n5. VERIFICATION")
print(f"\nRecords with null resolution_date (unresolved): {df3['resolution_date'].isnull().sum()}")
print(f"Records with resolved=False: {(df3['resolved'] == False).sum()}")

print("\n6. DETAILED INFORMATION")
print(df3.info())

print("\n" + "=" * 80)
print("DATE CONVERSION COMPLETE")
print("=" * 80)
# Out:
# ...
# CONVERTING DATE COLUMNS TO DATETIME - Fraud Alert History
# ...
#
# 1. DATA TYPES BEFORE CONVERSION
# alert_date         object
# resolution_date    object
# dtype: object
#
# 2. SAMPLE VALUES BEFORE CONVERSION
#       alert_id                  alert_date             resolution_date
# 0  alert134117  2025-08-03 13:29:58.950559                Not Resolved
# 1  alert183925  2024-10-09 09:41:15.203880  2024-10-11 02:41:15.203880
# 2  alert163439  2025-02-23 01:23:55.939700  2025-02-24 10:23:55.939700
# 3  alert164967  2025-07-08 21:50:16.926780  2025-07-09 19:50:16.926780
# 4  alert159661  2025-08-02 22:59:36.158113  2025-08-05 07:59:36.158113
# 5  alert180006  2025-03-05 13:01:59.435642  2025-03-06 20:01:59.435642
# 6  alert130778  2025-08-03 22:53:05.661964  2025-08-06 08:06:42.015035
# 7  alert122322  2021-12-18 21:00:55.193482  2021-12-19 18:00:55.193482
# 8  alert155954  2025-06-08 02:15:10.955244                Not Resolved
# ...

# %%
# Make first letter capital of alert_type column in df3 (fraud_alert_history)
df3['alert_type'] = df3['alert_type'].str.replace('_', ' ').str.title()

print("Updated 'alert_type' column:")
print(df3['alert_type'].value_counts())
print("\nSample of updated data:")
print(df3[['alert_id', 'transaction_id', 'alert_type', 'resolved']].head(10))
# Out:
# Updated 'alert_type' column:
# alert_type
# Unusual Time        507
# Frequent Failure    501
# Suspicious Login    498
# Unusual Amount      494
# Name: count, dtype: int64
#
# Sample of updated data:
#       alert_id transaction_id        alert_type  resolved
# 0  alert134117    txn10034117  Frequent Failure     False
# 1  alert183925    txn10083925  Frequent Failure      True
# 2  alert163439    txn10063439      Unusual Time      True
# 3  alert164967    txn10064967  Frequent Failure      True
# 4  alert159661    txn10059661  Frequent Failure      True
# 5  alert180006    txn10080006    Unusual Amount      True
# 6  alert130778    txn10030778    Unusual Amount      True
# 7  alert122322    txn10022322    Unusual Amount      True
# 8  alert155954    txn10055954    Unusual Amount     False
# 9  alert140444    txn10040444  Suspicious Login     False

# %%
df3['alert_type'] = df3['alert_type'].str.replace(' ', '_').str.title()

# %%
# Check for duplicate values in df4 (merchant_info)
print("=" * 80)
print("DUPLICATE VALUE ANALYSIS - Merchant Info")
print("=" * 80)

# 1. Check for complete duplicate rows
print("\n1. COMPLETE DUPLICATE ROWS")
duplicate_rows_df4 = df4.duplicated().sum()
print(f"Number of complete duplicate rows: {duplicate_rows_df4}")

if duplicate_rows_df4 > 0:
    print("\nSample duplicate rows:")
    print(df4[df4.duplicated(keep=False)].sort_values(by=list(df4.columns)).head(10))

# 2. Check for duplicates in specific columns
print("\n2. DUPLICATE VALUES IN KEY COLUMNS")

# Check merchant_id duplicates (should be unique)
merchant_id_duplicates = df4['merchant_id'].duplicated().sum()
print(f"\nDuplicate merchant_id: {merchant_id_duplicates}")
if merchant_id_duplicates > 0:
    print("Sample duplicate merchant_id values:")
    print(df4[df4['merchant_id'].duplicated(keep=False)].sort_values('merchant_id').head(10))

# Check merchant_name duplicates
merchant_name_duplicates = df4['merchant_name'].duplicated().sum()
print(f"\nDuplicate merchant_name: {merchant_name_duplicates}")
if merchant_name_duplicates > 0:
    print(f"Unique merchant names: {df4['merchant_name'].nunique()}")
    print(f"Total merchants: {len(df4)}")
    merchant_name_counts = df4['merchant_name'].value_counts()
    duplicate_names = merchant_name_counts[merchant_name_counts > 1]
    print(f"\nMerchant names appearing multiple times: {len(duplicate_names)}")
    if len(duplicate_names) > 0:
        print("\nTop 10 merchant names with most occurrences:")
        print(duplicate_names.head(10))

# 3. Check for duplicates based on combinations of columns
print("\n3. DUPLICATE COMBINATIONS")

# Same merchant_name + merchant_type
name_type_duplicates = df4.duplicated(subset=['merchant_name', 'merchant_type']).sum()
print(f"\nSame merchant_name + merchant_type: {name_type_duplicates}")

# Same merchant_name + region
name_region_duplicates = df4.duplicated(subset=['merchant_name', 'region']).sum()
print(f"Same merchant_name + region: {name_region_duplicates}")

# 4. Merchant type distribution
print("\n4. MERCHANT TYPE DISTRIBUTION")
print(df4['merchant_type'].value_counts())

# 5. Region distribution
print("\n5. REGION DISTRIBUTION")
print(df4['region'].value_counts())

# 6. Visualization of duplicates
print("\n6. CREATING VISUALIZATIONS...")

fig_dup_df4, axes_dup_df4 = plt.subplots(2, 2, figsize=(14, 10))
fig_dup_df4.suptitle('Duplicate Analysis - Merchant Info', fontsize=16, fontweight='bold')

# Plot 1: Duplicate counts by column
ax_dup1_df4 = axes_dup_df4[0, 0]
duplicate_data_df4 = pd.Series({
    'merchant_id': merchant_id_duplicates,
    'merchant_name': merchant_name_duplicates,
    'complete_rows': duplicate_rows_df4
})
duplicate_data_df4.plot(kind='bar', ax=ax_dup1_df4, color='coral', edgecolor='black')
ax_dup1_df4.set_title('Duplicate Counts by Type')
ax_dup1_df4.set_ylabel('Number of Duplicates')
ax_dup1_df4.set_xlabel('Column/Type')
ax_dup1_df4.tick_params(axis='x', rotation=45)

# Plot 2: Merchant type distribution
ax_dup2_df4 = axes_dup_df4[0, 1]
df4['merchant_type'].value_counts().plot(kind='bar', ax=ax_dup2_df4, color='skyblue', edgecolor='black')
ax_dup2_df4.set_title('Merchant Type Distribution')
ax_dup2_df4.set_ylabel('Count')
ax_dup2_df4.set_xlabel('Merchant Type')
ax_dup2_df4.tick_params(axis='x', rotation=45)

# Plot 3: Region distribution
ax_dup3_df4 = axes_dup_df4[1, 0]
df4['region'].value_counts().plot(kind='pie', ax=ax_dup3_df4, autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightyellow'])
ax_dup3_df4.set_title('Region Distribution')
ax_dup3_df4.set_ylabel('')

# Plot 4: Risk score distribution
ax_dup4_df4 = axes_dup_df4[1, 1]
df4['risk_score'].hist(bins=20, ax=ax_dup4_df4, color='salmon', edgecolor='black')
ax_dup4_df4.set_title('Risk Score Distribution')
ax_dup4_df4.set_xlabel('Risk Score')
ax_dup4_df4.set_ylabel('Frequency')
ax_dup4_df4.axvline(df4['risk_score'].mean(), color='red', linestyle='--', label=f'Mean: {df4["risk_score"].mean():.2f}')
ax_dup4_df4.legend()

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("DUPLICATE ANALYSIS COMPLETE - Merchant Info")
print("=" * 80)
# Out:
# ...
# DUPLICATE VALUE ANALYSIS - Merchant Info
# ...
#
# 1. COMPLETE DUPLICATE ROWS
# Number of complete duplicate rows: 0
#
# 2. DUPLICATE VALUES IN KEY COLUMNS
#
# Duplicate merchant_id: 0
#
# Duplicate merchant_name: 5
# Unique merchant names: 495
# Total merchants: 500
#
# Merchant names appearing multiple times: 5
#
# Top 10 merchant names with most occurrences:
# merchant_name
# Williams Group    2
# Brown Inc         2
# Ortiz and Sons    2
# Johnson Inc       2
# Jackson Group     2
# Name: count, dtype: int64
#
# 3. DUPLICATE COMBINATIONS
#
# Same merchant_name + merchant_type: 1
# Same merchant_name + region: 1
#
# 4. MERCHANT TYPE DISTRIBUTION
# merchant_type
# apparel        98
# electronics    91
# online         86
# food           80
# grocery        75
# transport      70
# Name: count, dtype: int64
#
# 5. REGION DISTRIBUTION
# region
# north      113
# east       107
# west       102
# central     95
# south       83
# Name: count, dtype: int64
#
# 6. CREATING VISUALIZATIONS...
# ...

# %%
# Check for missing values in df4 (merchant_info)
print("=" * 80)
print("MISSING VALUES ANALYSIS - Merchant Info")
print("=" * 80)

# 1. Total missing values
print("\n1. MISSING VALUES COUNT")
missing_values_df4 = df4.isnull().sum()
print(missing_values_df4)

# 2. Missing values percentage
print("\n2. MISSING VALUES PERCENTAGE")
missing_percentage_df4 = (df4.isnull().sum() / len(df4)) * 100
missing_summary_df4 = pd.DataFrame({
    'Column': df4.columns,
    'Missing_Count': missing_values_df4.values,
    'Missing_Percentage': missing_percentage_df4.values
})
print(missing_summary_df4)

# 3. Total missing values in dataset
total_missing_df4 = df4.isnull().sum().sum()
total_cells_df4 = df4.shape[0] * df4.shape[1]
overall_percentage_df4 = (total_missing_df4 / total_cells_df4) * 100

print(f"\n3. OVERALL SUMMARY")
print(f"Total missing values: {total_missing_df4}")
print(f"Total cells: {total_cells_df4}")
print(f"Overall missing percentage: {overall_percentage_df4:.2f}%")

# 4. Rows with any missing values
rows_with_missing_df4 = df4.isnull().any(axis=1).sum()
print(f"\n4. ROWS WITH MISSING VALUES")
print(f"Number of rows with at least one missing value: {rows_with_missing_df4}")
print(f"Percentage of rows with missing values: {(rows_with_missing_df4 / len(df4)) * 100:.2f}%")

# 5. Detailed analysis of missing values by column
print("\n5. DETAILED MISSING VALUE ANALYSIS")
for col in df4.columns:
    missing_count = df4[col].isnull().sum()
    if missing_count > 0:
        print(f"\n{col}:")
        print(f"  - Missing count: {missing_count}")
        print(f"  - Missing percentage: {(missing_count / len(df4)) * 100:.2f}%")

# 6. Visualization of missing values
print("\n6. CREATING VISUALIZATION...")

fig_missing_df4, ax_missing_df4 = plt.subplots(figsize=(10, 6))
missing_data_df4 = missing_values_df4[missing_values_df4 > 0]

if len(missing_data_df4) > 0:
    missing_data_df4.plot(kind='bar', ax=ax_missing_df4, color='coral', edgecolor='black')
    ax_missing_df4.set_title('Missing Values by Column - Merchant Info', fontsize=14, fontweight='bold')
    ax_missing_df4.set_ylabel('Count')
    ax_missing_df4.set_xlabel('Column')
    ax_missing_df4.tick_params(axis='x', rotation=45)
else:
    ax_missing_df4.text(0.5, 0.5, 'No Missing Values Found', ha='center', va='center', fontsize=14, fontweight='bold')
    ax_missing_df4.set_title('Missing Values by Column - Merchant Info', fontsize=14, fontweight='bold')
    ax_missing_df4.axis('off')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("MISSING VALUES ANALYSIS COMPLETE - Merchant Info")
print("=" * 80)
# Out:
# ...
# MISSING VALUES ANALYSIS - Merchant Info
# ...
#
# 1. MISSING VALUES COUNT
# merchant_id      0
# merchant_name    0
# merchant_type    0
# region           0
# onboard_date     0
# risk_score       0
# dtype: int64
#
# 2. MISSING VALUES PERCENTAGE
#           Column  Missing_Count  Missing_Percentage
# 0    merchant_id              0                 0.0
# 1  merchant_name              0                 0.0
# 2  merchant_type              0                 0.0
# 3         region              0                 0.0
# 4   onboard_date              0                 0.0
# 5     risk_score              0                 0.0
#
# 3. OVERALL SUMMARY
# Total missing values: 0
# Total cells: 3000
# Overall missing percentage: 0.00%
#
# 4. ROWS WITH MISSING VALUES
# Number of rows with at least one missing value: 0
# Percentage of rows with missing values: 0.00%
#
# 5. DETAILED MISSING VALUE ANALYSIS
#
# 6. CREATING VISUALIZATION...
# ...
# MISSING VALUES ANALYSIS COMPLETE - Merchant Info
# ...

# %%
# Check data types of df4 (merchant_info)
print("=" * 80)
print("DATA TYPE ANALYSIS - Merchant Info (df4)")
print("=" * 80)

print("\n1. DATA TYPES OF ALL COLUMNS")
print(df4.dtypes)

print("\n2. DETAILED DATA TYPE INFORMATION")
print(df4.info())

print("\n3. DATA TYPE SUMMARY")
dtype_summary_df4 = df4.dtypes.value_counts()
print("\nCount by Data Type:")
print(dtype_summary_df4)

print("\n4. COLUMN-WISE DATA TYPE DETAILS")
for col in df4.columns:
    print(f"\n{col}:")
    print(f"  - Data Type: {df4[col].dtype}")
    print(f"  - Sample Values: {df4[col].head(3).tolist()}")

print("\n" + "=" * 80)
print("CONVERTING DATA TYPES")
print("=" * 80)

# Convert onboard_date to datetime
df4['onboard_date'] = pd.to_datetime(df4['onboard_date'])

print("\n5. DATA TYPES AFTER CONVERSION")
print(df4.dtypes)

print("\n6. UPDATED DATA TYPE INFORMATION")
print(df4.info())

print("\n7. VERIFICATION")
print("\nSample of updated data:")
print(df4[['merchant_id', 'merchant_name', 'onboard_date', 'risk_score']].head(10))

print("\n" + "=" * 80)
print("DATA TYPE CONVERSION COMPLETE")
print("=" * 80)
# Out:
# ...
# DATA TYPE ANALYSIS - Merchant Info (df4)
# ...
#
# 1. DATA TYPES OF ALL COLUMNS
# merchant_id       object
# merchant_name     object
# merchant_type     object
# region            object
# onboard_date      object
# risk_score       float64
# dtype: object
#
# 2. DETAILED DATA TYPE INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   merchant_id    500 non-null    object
#  1   merchant_name  500 non-null    object
#  2   merchant_type  500 non-null    object
#  3   region         500 non-null    object
#  4   onboard_date   500 non-null    object
#  5   risk_score     500 non-null    float64
# dtypes: float64(1), object(5)
# memory usage: 23.6+ KB
# None
#
# 3. DATA TYPE SUMMARY
#
# Count by Data Type:
# object     5
# float64    1
# Name: count, dtype: int64
#
# 4. COLUMN-WISE DATA TYPE DETAILS
#
# merchant_id:
# ...

# %%
# Make first letter capital of required columns in df4 (merchant_info)
df4['merchant_name'] = df4['merchant_name'].str.title()
df4['merchant_type'] = df4['merchant_type'].str.capitalize()
df4['region'] = df4['region'].str.capitalize()

print("Updated columns with capitalized first letters:")
print("\nMerchant Type values:")
print(df4['merchant_type'].value_counts())
print("\nRegion values:")
print(df4['region'].value_counts())
print("\nSample of updated data:")
print(df4[['merchant_id', 'merchant_name', 'merchant_type', 'region', 'risk_score']].head(10))
# Out:
# Updated columns with capitalized first letters:
#
# Merchant Type values:
# merchant_type
# Apparel        98
# Electronics    91
# Online         86
# Food           80
# Grocery        75
# Transport      70
# Name: count, dtype: int64
#
# Region values:
# region
# North      113
# East       107
# West       102
# Central     95
# South       83
# Name: count, dtype: int64
#
# Sample of updated data:
#   merchant_id                merchant_name merchant_type region  risk_score
# 0   merch1000                 Anderson Inc       Grocery  North        0.07
# 1   merch1001      Rojas, Newton And White        Online  North        0.29
# 2   merch1002                   Knox-Reyes          Food   West        0.20
# 3   merch1003  Joseph, Serrano And Gilmore       Grocery  North        0.14
# 4   merch1004                  Brown-Jones          Food  North        0.32
# 5   merch1005                Russell-Jones          Food  North        0.29
# ...

# %%
# Check for duplicate values in df5 (upi_account_details)
print("=" * 80)
print("DUPLICATE VALUE ANALYSIS - UPI Account Details")
print("=" * 80)

# 1. Check for complete duplicate rows
print("\n1. COMPLETE DUPLICATE ROWS")
duplicate_rows_df5 = df5.duplicated().sum()
print(f"Number of complete duplicate rows: {duplicate_rows_df5}")

if duplicate_rows_df5 > 0:
    print("\nSample duplicate rows:")
    print(df5[df5.duplicated(keep=False)].sort_values(by=list(df5.columns)).head(10))

# 2. Check for duplicates in specific columns
print("\n2. DUPLICATE VALUES IN KEY COLUMNS")

# Check upi_id duplicates (should be unique)
upi_id_duplicates = df5['upi_id'].duplicated().sum()
print(f"\nDuplicate upi_id: {upi_id_duplicates}")
if upi_id_duplicates > 0:
    print("Sample duplicate upi_id values:")
    print(df5[df5['upi_id'].duplicated(keep=False)].sort_values('upi_id').head(10))

# Check customer_id duplicates (customers can have multiple UPI accounts)
customer_id_duplicates_df5 = df5['customer_id'].duplicated().sum()
print(f"\nDuplicate customer_id: {customer_id_duplicates_df5}")
print(f"Unique customers: {df5['customer_id'].nunique()}")
print(f"Total UPI accounts: {len(df5)}")

# Customers with multiple UPI accounts
customer_upi_counts = df5['customer_id'].value_counts()
multiple_upi_accounts = customer_upi_counts[customer_upi_counts > 1]
print(f"\nCustomers with multiple UPI accounts: {len(multiple_upi_accounts)}")
if len(multiple_upi_accounts) > 0:
    print("\nTop 10 customers with most UPI accounts:")
    print(multiple_upi_accounts.head(10))

# 3. Check for duplicates based on combinations of columns
print("\n3. DUPLICATE COMBINATIONS")

# Same customer + same bank
customer_bank_duplicates = df5.duplicated(subset=['customer_id', 'bank_name']).sum()
print(f"\nSame customer with same bank: {customer_bank_duplicates}")

# Same customer + same account type
customer_account_type_duplicates = df5.duplicated(subset=['customer_id', 'account_type']).sum()
print(f"Same customer with same account type: {customer_account_type_duplicates}")

# 4. Bank distribution
print("\n4. BANK DISTRIBUTION")
print(df5['bank_name'].value_counts())

# 5. Account type distribution
print("\n5. ACCOUNT TYPE DISTRIBUTION")
print(df5['account_type'].value_counts())

# 6. Status distribution
print("\n6. STATUS DISTRIBUTION")
print(df5['status'].value_counts())

# 7. Visualization of duplicates
print("\n7. CREATING VISUALIZATIONS...")

fig_dup_df5, axes_dup_df5 = plt.subplots(2, 2, figsize=(14, 10))
fig_dup_df5.suptitle('Duplicate Analysis - UPI Account Details', fontsize=16, fontweight='bold')

# Plot 1: Duplicate counts by column
ax_dup1_df5 = axes_dup_df5[0, 0]
duplicate_data_df5 = pd.Series({
    'upi_id': upi_id_duplicates,
    'customer_id': customer_id_duplicates_df5,
    'complete_rows': duplicate_rows_df5
})
duplicate_data_df5.plot(kind='bar', ax=ax_dup1_df5, color='coral', edgecolor='black')
ax_dup1_df5.set_title('Duplicate Counts by Type')
ax_dup1_df5.set_ylabel('Number of Duplicates')
ax_dup1_df5.set_xlabel('Column/Type')
ax_dup1_df5.tick_params(axis='x', rotation=45)

# Plot 2: Customers with multiple UPI accounts
ax_dup2_df5 = axes_dup_df5[0, 1]
if len(multiple_upi_accounts) > 0:
    multiple_upi_accounts.head(15).plot(kind='bar', ax=ax_dup2_df5, color='skyblue', edgecolor='black')
    ax_dup2_df5.set_title('Top 15 Customers with Multiple UPI Accounts')
    ax_dup2_df5.set_ylabel('Number of UPI Accounts')
    ax_dup2_df5.set_xlabel('Customer ID')
    ax_dup2_df5.tick_params(axis='x', rotation=45)
else:
    ax_dup2_df5.text(0.5, 0.5, 'No Customers with Multiple UPI Accounts', ha='center', va='center', fontsize=12)
    ax_dup2_df5.set_title('Customers with Multiple UPI Accounts')

# Plot 3: Bank distribution
ax_dup3_df5 = axes_dup_df5[1, 0]
df5['bank_name'].value_counts().plot(kind='bar', ax=ax_dup3_df5, color='lightgreen', edgecolor='black')
ax_dup3_df5.set_title('Bank Distribution')
ax_dup3_df5.set_ylabel('Count')
ax_dup3_df5.set_xlabel('Bank Name')
ax_dup3_df5.tick_params(axis='x', rotation=45)

# Plot 4: Account type distribution
ax_dup4_df5 = axes_dup_df5[1, 1]
df5['account_type'].value_counts().plot(kind='pie', ax=ax_dup4_df5, autopct='%1.1f%%', colors=['lightblue', 'lightcoral', 'lightgreen'])
ax_dup4_df5.set_title('Account Type Distribution')
ax_dup4_df5.set_ylabel('')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("DUPLICATE ANALYSIS COMPLETE - UPI Account Details")
print("=" * 80)
# Out:
# ...
# DUPLICATE VALUE ANALYSIS - UPI Account Details
# ...
#
# 1. COMPLETE DUPLICATE ROWS
# Number of complete duplicate rows: 0
#
# 2. DUPLICATE VALUES IN KEY COLUMNS
#
# Duplicate upi_id: 0
#
# Duplicate customer_id: 4967
# Unique customers: 7033
# Total UPI accounts: 12000
#
# Customers with multiple UPI accounts: 3309
#
# Top 10 customers with most UPI accounts:
# customer_id
# cust109942    7
# cust109685    7
# cust105966    6
# cust108227    6
# cust100902    6
# cust105718    6
# cust103519    6
# cust104708    6
# cust106429    6
# cust106552    6
# Name: count, dtype: int64
#
# 3. DUPLICATE COMBINATIONS
#
# Same customer with same bank: 1086
# Same customer with same account type: 2082
#
# 4. BANK DISTRIBUTION
# bank_name
# sbi      2036
# kotak    2010
# icici    2001
# pnb      1992
# hdfc     1990
# axis     1971
# Name: count, dtype: int64
#
# 5. ACCOUNT TYPE DISTRIBUTION
# account_type
# current               4031
# savings               4027
# credit_card_linked    3942
# ...

# %%
# Check for missing values in df5 (upi_account_details)
print("=" * 80)
print("MISSING VALUES ANALYSIS - UPI Account Details")
print("=" * 80)

# 1. Total missing values
print("\n1. MISSING VALUES COUNT")
missing_values_df5 = df5.isnull().sum()
print(missing_values_df5)

# 2. Missing values percentage
print("\n2. MISSING VALUES PERCENTAGE")
missing_percentage_df5 = (df5.isnull().sum() / len(df5)) * 100
missing_summary_df5 = pd.DataFrame({
    'Column': df5.columns,
    'Missing_Count': missing_values_df5.values,
    'Missing_Percentage': missing_percentage_df5.values
})
print(missing_summary_df5)

# 3. Total missing values in dataset
total_missing_df5 = df5.isnull().sum().sum()
total_cells_df5 = df5.shape[0] * df5.shape[1]
overall_percentage_df5 = (total_missing_df5 / total_cells_df5) * 100

print(f"\n3. OVERALL SUMMARY")
print(f"Total missing values: {total_missing_df5}")
print(f"Total cells: {total_cells_df5}")
print(f"Overall missing percentage: {overall_percentage_df5:.2f}%")

# 4. Rows with any missing values
rows_with_missing_df5 = df5.isnull().any(axis=1).sum()
print(f"\n4. ROWS WITH MISSING VALUES")
print(f"Number of rows with at least one missing value: {rows_with_missing_df5}")
print(f"Percentage of rows with missing values: {(rows_with_missing_df5 / len(df5)) * 100:.2f}%")

# 5. Detailed analysis of missing values by column
print("\n5. DETAILED MISSING VALUE ANALYSIS")
for col in df5.columns:
    missing_count = df5[col].isnull().sum()
    if missing_count > 0:
        print(f"\n{col}:")
        print(f"  - Missing count: {missing_count}")
        print(f"  - Missing percentage: {(missing_count / len(df5)) * 100:.2f}%")

# 6. Visualization of missing values
print("\n6. CREATING VISUALIZATION...")

fig_missing_df5, ax_missing_df5 = plt.subplots(figsize=(10, 6))
missing_data_df5 = missing_values_df5[missing_values_df5 > 0]

if len(missing_data_df5) > 0:
    missing_data_df5.plot(kind='bar', ax=ax_missing_df5, color='coral', edgecolor='black')
    ax_missing_df5.set_title('Missing Values by Column - UPI Account Details', fontsize=14, fontweight='bold')
    ax_missing_df5.set_ylabel('Count')
    ax_missing_df5.set_xlabel('Column')
    ax_missing_df5.tick_params(axis='x', rotation=45)
else:
    ax_missing_df5.text(0.5, 0.5, 'No Missing Values Found', ha='center', va='center', fontsize=14, fontweight='bold')
    ax_missing_df5.set_title('Missing Values by Column - UPI Account Details', fontsize=14, fontweight='bold')
    ax_missing_df5.axis('off')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("MISSING VALUES ANALYSIS COMPLETE - UPI Account Details")
print("=" * 80)
# Out:
# ...
# MISSING VALUES ANALYSIS - UPI Account Details
# ...
#
# 1. MISSING VALUES COUNT
# upi_id          0
# customer_id     0
# bank_name       0
# account_type    0
# date_added      0
# status          0
# dtype: int64
#
# 2. MISSING VALUES PERCENTAGE
#          Column  Missing_Count  Missing_Percentage
# 0        upi_id              0                 0.0
# 1   customer_id              0                 0.0
# 2     bank_name              0                 0.0
# 3  account_type              0                 0.0
# 4    date_added              0                 0.0
# 5        status              0                 0.0
#
# 3. OVERALL SUMMARY
# Total missing values: 0
# Total cells: 72000
# Overall missing percentage: 0.00%
#
# 4. ROWS WITH MISSING VALUES
# Number of rows with at least one missing value: 0
# Percentage of rows with missing values: 0.00%
#
# 5. DETAILED MISSING VALUE ANALYSIS
#
# 6. CREATING VISUALIZATION...
# ...
# MISSING VALUES ANALYSIS COMPLETE - UPI Account Details
# ...

# %%
# Convert date_added column to datetime format in df5 (upi_account_details)
print("=" * 80)
print("CONVERTING DATA TYPES - UPI Account Details")
print("=" * 80)

print("\n1. DATA TYPES BEFORE CONVERSION")
print(df5.dtypes)

print("\n2. SAMPLE VALUES BEFORE CONVERSION")
print(df5[['upi_id', 'customer_id', 'date_added', 'status']].head(10))

# Convert date_added to datetime
df5['date_added'] = pd.to_datetime(df5['date_added'])

print("\n3. DATA TYPES AFTER CONVERSION")
print(df5.dtypes)

print("\n4. UPDATED DATA TYPE INFORMATION")
print(df5.info())

print("\n5. SAMPLE VALUES AFTER CONVERSION")
print(df5[['upi_id', 'customer_id', 'date_added', 'status']].head(10))

print("\n6. VERIFICATION")
print(f"\nDate range: {df5['date_added'].min()} to {df5['date_added'].max()}")

print("\n" + "=" * 80)
print("DATA TYPE CONVERSION COMPLETE")
print("=" * 80)
# Out:
# ...
# CONVERTING DATA TYPES - UPI Account Details
# ...
#
# 1. DATA TYPES BEFORE CONVERSION
# upi_id          object
# customer_id     object
# bank_name       object
# account_type    object
# date_added      object
# status          object
# dtype: object
#
# 2. SAMPLE VALUES BEFORE CONVERSION
#               upi_id customer_id  date_added  status
# 0  elizabeth4408@upi  cust106759  2022-02-22  active
# 1     daniel5127@upi  cust104765  2022-04-02  active
# 2      heidi2675@upi  cust102710  2023-12-19  active
# 3        dr.3519@upi  cust107076  2025-01-23  active
# 4     jeremy9552@upi  cust102202  2025-07-18  active
# 5    michael1769@upi  cust108834  2024-04-21  active
# 6     dennis4906@upi  cust106735  2021-06-13  active
# 7       omar6644@upi  cust106890  2024-09-10  active
# 8    rachael7253@upi  cust100697  2024-01-11  active
# 9     ashley3227@upi  cust109510  2023-02-08  active
#
# 3. DATA TYPES AFTER CONVERSION
# upi_id                  object
# customer_id             object
# ...

# %%
print(df5.dtypes)
# Out:
# upi_id                  object
# customer_id             object
# bank_name               object
# account_type            object
# date_added      datetime64[ns]
# status                  object
# dtype: object

# %%
# Make first letter capital of required columns in df5 (upi_account_details)
df5['bank_name'] = df5['bank_name'].str.upper()
df5['account_type'] = df5['account_type'].str.replace('_', ' ').str.title()
df5['status'] = df5['status'].str.capitalize()

print("Updated columns with capitalized first letters:")
print("\nBank Name values:")
print(df5['bank_name'].value_counts())
print("\nAccount Type values:")
print(df5['account_type'].value_counts())
print("\nStatus values:")
print(df5['status'].value_counts())
print("\nSample of updated data:")
print(df5[['upi_id', 'customer_id', 'bank_name', 'account_type', 'status']].head(10))
# Out:
# Updated columns with capitalized first letters:
#
# Bank Name values:
# bank_name
# SBI      2036
# KOTAK    2010
# ICICI    2001
# PNB      1992
# HDFC     1990
# AXIS     1971
# Name: count, dtype: int64
#
# Account Type values:
# account_type
# Current               4031
# Savings               4027
# Credit Card Linked    3942
# Name: count, dtype: int64
#
# Status values:
# status
# Active       11148
# Suspended      468
# Blocked        384
# Name: count, dtype: int64
#
# Sample of updated data:
#               upi_id customer_id bank_name        account_type  status
# 0  elizabeth4408@upi  cust106759       SBI             Current  Active
# 1     daniel5127@upi  cust104765      HDFC             Savings  Active
# 2      heidi2675@upi  cust102710      AXIS             Savings  Active
# 3        dr.3519@upi  cust107076      AXIS  Credit Card Linked  Active
# 4     jeremy9552@upi  cust102202       SBI             Current  Active
# ...

# %%
df6.head()
# Out:
#   transaction_id            upi_id customer_id                   timestamp  \
# 0    txn10000000    marisa9078@upi  cust101488  2025-06-04 21:36:19.632258
# 1    txn10000001  michelle5950@upi  cust107876  2025-05-22 04:26:44.200117
# 2    txn10000002   jeffery4732@upi  cust100901  2025-08-02 02:34:14.690327
# 3    txn10000003      troy1833@upi  cust105890  2025-01-30 03:53:31.110447
# 4    txn10000004     tammy4986@upi  cust106780  2025-07-05 21:36:52.813878
#
#    amount  transaction_type merchant_id counterparty_upi   status  device_id  \
# 0    9.88              send         NaN     user6545@upi  success  dev101488
# 1   76.25           receive         NaN     user3199@upi  success  dev107876
# 2   26.44  merchant_payment   merch1113     user4690@upi  success  dev100901
# 3   84.43              send         NaN     user1982@upi  success  dev105890
# 4   10.33           receive         NaN     user4914@upi  success  dev106780
#
# ...

# %%
df6.dtypes
# Out:
# transaction_id       object
# upi_id               object
# customer_id          object
# timestamp            object
# amount              float64
# transaction_type     object
# merchant_id          object
# counterparty_upi     object
# status               object
# device_id            object
# device_type          object
# channel              object
# fraud_flag             bool
# reversal_flag          bool
# failure_reason       object
# dtype: object

# %%
# Convert timestamp column to datetime format in df6 (upi_transaction_history)
print("=" * 80)
print("CONVERTING DATA TYPES - UPI Transaction History")
print("=" * 80)

print("\n1. DATA TYPES BEFORE CONVERSION")
print(df6.dtypes)

print("\n2. SAMPLE VALUES BEFORE CONVERSION")
print(df6[['transaction_id', 'customer_id', 'timestamp', 'amount', 'status']].head(10))

# Convert timestamp to datetime
df6['timestamp'] = pd.to_datetime(df6['timestamp'])

print("\n3. DATA TYPES AFTER CONVERSION")
print(df6.dtypes)

print("\n4. UPDATED DATA TYPE INFORMATION")
print(df6.info())

print("\n5. SAMPLE VALUES AFTER CONVERSION")
print(df6[['transaction_id', 'customer_id', 'timestamp', 'amount', 'status']].head(10))

print("\n6. VERIFICATION")
print(f"\nTimestamp range: {df6['timestamp'].min()} to {df6['timestamp'].max()}")

print("\n" + "=" * 80)
print("DATA TYPE CONVERSION COMPLETE")
print("=" * 80)
# Out:
# ...
# CONVERTING DATA TYPES - UPI Transaction History
# ...
#
# 1. DATA TYPES BEFORE CONVERSION
# transaction_id       object
# upi_id               object
# customer_id          object
# timestamp            object
# amount              float64
# transaction_type     object
# merchant_id          object
# counterparty_upi     object
# status               object
# device_id            object
# device_type          object
# channel              object
# fraud_flag             bool
# reversal_flag          bool
# failure_reason       object
# dtype: object
#
# 2. SAMPLE VALUES BEFORE CONVERSION
#   transaction_id customer_id                   timestamp  amount   status
# 0    txn10000000  cust101488  2025-06-04 21:36:19.632258    9.88  success
# 1    txn10000001  cust107876  2025-05-22 04:26:44.200117   76.25  success
# 2    txn10000002  cust100901  2025-08-02 02:34:14.690327   26.44  success
# 3    txn10000003  cust105890  2025-01-30 03:53:31.110447   84.43  success
# ...

# %%
# Check for missing values in df6 (upi_transaction_history)
print("=" * 80)
print("MISSING VALUES ANALYSIS - UPI Transaction History")
print("=" * 80)

# 1. Total missing values
print("\n1. MISSING VALUES COUNT")
missing_values_df6 = df6.isnull().sum()
print(missing_values_df6)

# 2. Missing values percentage
print("\n2. MISSING VALUES PERCENTAGE")
missing_percentage_df6 = (df6.isnull().sum() / len(df6)) * 100
missing_summary_df6 = pd.DataFrame({
    'Column': df6.columns,
    'Missing_Count': missing_values_df6.values,
    'Missing_Percentage': missing_percentage_df6.values
})
print(missing_summary_df6)

# 3. Total missing values in dataset
total_missing_df6 = df6.isnull().sum().sum()
total_cells_df6 = df6.shape[0] * df6.shape[1]
overall_percentage_df6 = (total_missing_df6 / total_cells_df6) * 100

print(f"\n3. OVERALL SUMMARY")
print(f"Total missing values: {total_missing_df6}")
print(f"Total cells: {total_cells_df6}")
print(f"Overall missing percentage: {overall_percentage_df6:.2f}%")

# 4. Rows with any missing values
rows_with_missing_df6 = df6.isnull().any(axis=1).sum()
print(f"\n4. ROWS WITH MISSING VALUES")
print(f"Number of rows with at least one missing value: {rows_with_missing_df6}")
print(f"Percentage of rows with missing values: {(rows_with_missing_df6 / len(df6)) * 100:.2f}%")

# 5. Detailed analysis of missing values by column
print("\n5. DETAILED MISSING VALUE ANALYSIS")
for col in df6.columns:
    missing_count = df6[col].isnull().sum()
    if missing_count > 0:
        print(f"\n{col}:")
        print(f"  - Missing count: {missing_count}")
        print(f"  - Missing percentage: {(missing_count / len(df6)) * 100:.2f}%")
        print(f"  - Data type: {df6[col].dtype}")

# 6. Analysis by transaction status
print("\n6. MISSING VALUES BY TRANSACTION STATUS")
if 'status' in df6.columns:
    print("\nMissing merchant_id by status:")
    print(df6.groupby('status')['merchant_id'].apply(lambda x: x.isnull().sum()))
    
    print("\nMissing failure_reason by status:")
    print(df6.groupby('status')['failure_reason'].apply(lambda x: x.isnull().sum()))

# 7. Visualization of missing values
print("\n7. CREATING VISUALIZATION...")

fig_missing_df6, axes_missing_df6 = plt.subplots(1, 2, figsize=(14, 6))
fig_missing_df6.suptitle('Missing Values Analysis - UPI Transaction History', fontsize=16, fontweight='bold')

# Plot 1: Missing values by column
ax_missing1_df6 = axes_missing_df6[0]
missing_data_df6 = missing_values_df6[missing_values_df6 > 0]

if len(missing_data_df6) > 0:
    missing_data_df6.plot(kind='bar', ax=ax_missing1_df6, color='coral', edgecolor='black')
    ax_missing1_df6.set_title('Missing Values by Column')
    ax_missing1_df6.set_ylabel('Count')
    ax_missing1_df6.set_xlabel('Column')
    ax_missing1_df6.tick_params(axis='x', rotation=45)
else:
    ax_missing1_df6.text(0.5, 0.5, 'No Missing Values Found', ha='center', va='center', fontsize=14, fontweight='bold')
    ax_missing1_df6.set_title('Missing Values by Column')
    ax_missing1_df6.axis('off')

# Plot 2: Missing percentage visualization
ax_missing2_df6 = axes_missing_df6[1]
if len(missing_data_df6) > 0:
    missing_pct_data = missing_percentage_df6[missing_values_df6 > 0]
    missing_pct_data.plot(kind='bar', ax=ax_missing2_df6, color='salmon', edgecolor='black')
    ax_missing2_df6.set_title('Missing Values Percentage by Column')
    ax_missing2_df6.set_ylabel('Percentage (%)')
    ax_missing2_df6.set_xlabel('Column')
    ax_missing2_df6.tick_params(axis='x', rotation=45)
else:
    ax_missing2_df6.text(0.5, 0.5, 'No Missing Values Found', ha='center', va='center', fontsize=14, fontweight='bold')
    ax_missing2_df6.set_title('Missing Values Percentage')
    ax_missing2_df6.axis('off')

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("MISSING VALUES ANALYSIS COMPLETE - UPI Transaction History")
print("=" * 80)
# Out:
# ...
# MISSING VALUES ANALYSIS - UPI Transaction History
# ...
#
# 1. MISSING VALUES COUNT
# transaction_id          0
# upi_id                  0
# customer_id             0
# timestamp               0
# amount                  0
# transaction_type        0
# merchant_id         69851
# counterparty_upi        0
# status                  0
# device_id               0
# device_type             0
# channel                 0
# fraud_flag              0
# reversal_flag           0
# failure_reason      94129
# dtype: int64
#
# 2. MISSING VALUES PERCENTAGE
#               Column  Missing_Count  Missing_Percentage
# 0     transaction_id              0               0.000
# 1             upi_id              0               0.000
# 2        customer_id              0               0.000
# 3          timestamp              0               0.000
# 4             amount              0               0.000
# 5   transaction_type              0               0.000
# ...

# %%
# Check for duplicate values in df6 (upi_transaction_history)
print("=" * 80)
print("DUPLICATE VALUE ANALYSIS - UPI Transaction History")
print("=" * 80)

# 1. Check for complete duplicate rows
print("\n1. COMPLETE DUPLICATE ROWS")
duplicate_rows_df6 = df6.duplicated().sum()
print(f"Number of complete duplicate rows: {duplicate_rows_df6}")

if duplicate_rows_df6 > 0:
    print("\nSample duplicate rows:")
    print(df6[df6.duplicated(keep=False)].sort_values(by=list(df6.columns)).head(10))

# 2. Check for duplicates in specific columns
print("\n2. DUPLICATE VALUES IN KEY COLUMNS")

# Check transaction_id duplicates (should be unique)
transaction_id_duplicates_df6 = df6['transaction_id'].duplicated().sum()
print(f"\nDuplicate transaction_id: {transaction_id_duplicates_df6}")
if transaction_id_duplicates_df6 > 0:
    print("Sample duplicate transaction_id values:")
    print(df6[df6['transaction_id'].duplicated(keep=False)].sort_values('transaction_id').head(10))

# Check customer_id duplicates (customers can have multiple transactions)
customer_id_duplicates_df6 = df6['customer_id'].duplicated().sum()
print(f"\nDuplicate customer_id: {customer_id_duplicates_df6}")
print(f"Unique customers: {df6['customer_id'].nunique()}")
print(f"Total transactions: {len(df6)}")

# Customers with multiple transactions
customer_transaction_counts = df6['customer_id'].value_counts()
print(f"\nTop 10 customers with most transactions:")
print(customer_transaction_counts.head(10))

# 3. Check for duplicates based on combinations of columns
print("\n3. DUPLICATE COMBINATIONS")

# Same customer + same timestamp
customer_timestamp_duplicates = df6.duplicated(subset=['customer_id', 'timestamp']).sum()
print(f"\nSame customer + timestamp: {customer_timestamp_duplicates}")

# Same upi_id + timestamp
upi_timestamp_duplicates = df6.duplicated(subset=['upi_id', 'timestamp']).sum()
print(f"Same upi_id + timestamp: {upi_timestamp_duplicates}")

# 4. Transaction type distribution
print("\n4. TRANSACTION TYPE DISTRIBUTION")
print(df6['transaction_type'].value_counts())

# 5. Status distribution
print("\n5. STATUS DISTRIBUTION")
print(df6['status'].value_counts())

# 6. Device type distribution
print("\n6. DEVICE TYPE DISTRIBUTION")
print(df6['device_type'].value_counts())

# 7. Channel distribution
print("\n7. CHANNEL DISTRIBUTION")
print(df6['channel'].value_counts())

# 8. Visualization of duplicates
print("\n8. CREATING VISUALIZATIONS...")

fig_dup_df6, axes_dup_df6 = plt.subplots(2, 3, figsize=(18, 10))
fig_dup_df6.suptitle('Duplicate Analysis - UPI Transaction History', fontsize=16, fontweight='bold')

# Plot 1: Duplicate counts by column
ax_dup1_df6 = axes_dup_df6[0, 0]
duplicate_data_df6 = pd.Series({
    'transaction_id': transaction_id_duplicates_df6,
    'customer_id': customer_id_duplicates_df6,
    'complete_rows': duplicate_rows_df6
})
duplicate_data_df6.plot(kind='bar', ax=ax_dup1_df6, color='coral', edgecolor='black')
ax_dup1_df6.set_title('Duplicate Counts by Type')
ax_dup1_df6.set_ylabel('Number of Duplicates')
ax_dup1_df6.set_xlabel('Column/Type')
ax_dup1_df6.tick_params(axis='x', rotation=45)

# Plot 2: Top customers by transaction count
ax_dup2_df6 = axes_dup_df6[0, 1]
customer_transaction_counts.head(15).plot(kind='bar', ax=ax_dup2_df6, color='skyblue', edgecolor='black')
ax_dup2_df6.set_title('Top 15 Customers by Transaction Count')
ax_dup2_df6.set_ylabel('Number of Transactions')
ax_dup2_df6.set_xlabel('Customer ID')
ax_dup2_df6.tick_params(axis='x', rotation=45)

# Plot 3: Transaction type distribution
ax_dup3_df6 = axes_dup_df6[0, 2]
df6['transaction_type'].value_counts().plot(kind='bar', ax=ax_dup3_df6, color='lightgreen', edgecolor='black')
ax_dup3_df6.set_title('Transaction Type Distribution')
ax_dup3_df6.set_ylabel('Count')
ax_dup3_df6.set_xlabel('Transaction Type')
ax_dup3_df6.tick_params(axis='x', rotation=45)

# Plot 4: Status distribution
ax_dup4_df6 = axes_dup_df6[1, 0]
df6['status'].value_counts().plot(kind='pie', ax=ax_dup4_df6, autopct='%1.1f%%', colors=['green', 'red'])
ax_dup4_df6.set_title('Transaction Status Distribution')
ax_dup4_df6.set_ylabel('')

# Plot 5: Device type distribution
ax_dup5_df6 = axes_dup_df6[1, 1]
df6['device_type'].value_counts().plot(kind='bar', ax=ax_dup5_df6, color='salmon', edgecolor='black')
ax_dup5_df6.set_title('Device Type Distribution')
ax_dup5_df6.set_ylabel('Count')
ax_dup5_df6.set_xlabel('Device Type')
ax_dup5_df6.tick_params(axis='x', rotation=45)

# Plot 6: Channel distribution
ax_dup6_df6 = axes_dup_df6[1, 2]
df6['channel'].value_counts().plot(kind='bar', ax=ax_dup6_df6, color='lightyellow', edgecolor='black')
ax_dup6_df6.set_title('Channel Distribution')
ax_dup6_df6.set_ylabel('Count')
ax_dup6_df6.set_xlabel('Channel')
ax_dup6_df6.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print("\n" + "=" * 80)
print("DUPLICATE ANALYSIS COMPLETE - UPI Transaction History")
print("=" * 80)
# Out:
# ...
# DUPLICATE VALUE ANALYSIS - UPI Transaction History
# ...
#
# 1. COMPLETE DUPLICATE ROWS
# Number of complete duplicate rows: 0
#
# 2. DUPLICATE VALUES IN KEY COLUMNS
#
# Duplicate transaction_id: 0
#
# Duplicate customer_id: 92968
# Unique customers: 7032
# Total transactions: 100000
#
# Top 10 customers with most transactions:
# customer_id
# cust101660    71
# cust105966    59
# cust102584    57
# cust100835    56
# cust103960    56
# cust104708    55
# cust104396    54
# cust102733    54
# cust106552    54
# cust103560    53
# Name: count, dtype: int64
#
# 3. DUPLICATE COMBINATIONS
#
# Same customer + timestamp: 0
# Same upi_id + timestamp: 0
#
# 4. TRANSACTION TYPE DISTRIBUTION
# transaction_type
# send                35032
# receive             34819
# merchant_payment    25097
# bill_pay             5052
# Name: count, dtype: int64
#
# 5. STATUS DISTRIBUTION
# status
# success    92140
# failed      5871
# pending     1989
# Name: count, dtype: int64
#
# 6. DEVICE TYPE DISTRIBUTION
# ...

# %%
# Make first letter capital of required columns in df6 (upi_transaction_history)
df6['transaction_type'] = df6['transaction_type'].str.replace('_', ' ').str.title()
df6['status'] = df6['status'].str.capitalize()
df6['device_type'] = df6['device_type'].str.replace('_', ' ').str.title()
df6['channel'] = df6['channel'].str.replace('_', ' ').str.title()

print("Updated columns with capitalized first letters:")
print("\nTransaction Type values:")
print(df6['transaction_type'].value_counts())
print("\nStatus values:")
print(df6['status'].value_counts())
print("\nDevice Type values:")
print(df6['device_type'].value_counts())
print("\nChannel values:")
print(df6['channel'].value_counts())
print("\nSample of updated data:")
print(df6[['transaction_id', 'customer_id', 'transaction_type', 'status', 'device_type', 'channel']].head(10))
# Out:
# Updated columns with capitalized first letters:
#
# Transaction Type values:
# transaction_type
# Send                35032
# Receive             34819
# Merchant Payment    25097
# Bill Pay             5052
# Name: count, dtype: int64
#
# Status values:
# status
# Success    92140
# Failed      5871
# Pending     1989
# Name: count, dtype: int64
#
# Device Type values:
# device_type
# Feature Phone    25596
# Android          25145
# Ios              24783
# Tablet           24476
# Name: count, dtype: int64
#
# Channel values:
# channel
# App        33365
# Intent     33356
# Qr Code    33279
# Name: count, dtype: int64
#
# Sample of updated data:
#   transaction_id customer_id  transaction_type   status    device_type  \
# 0    txn10000000  cust101488              Send  Success  Feature Phone
# 1    txn10000001  cust107876           Receive  Success            Ios
# 2    txn10000002  cust100901  Merchant Payment  Success        Android
# ...

# %%
df6.head()
# Out:
#   transaction_id            upi_id customer_id                  timestamp  \
# 0    txn10000000    marisa9078@upi  cust101488 2025-06-04 21:36:19.632258
# 1    txn10000001  michelle5950@upi  cust107876 2025-05-22 04:26:44.200117
# 2    txn10000002   jeffery4732@upi  cust100901 2025-08-02 02:34:14.690327
# 3    txn10000003      troy1833@upi  cust105890 2025-01-30 03:53:31.110447
# 4    txn10000004     tammy4986@upi  cust106780 2025-07-05 21:36:52.813878
#
#    amount  transaction_type merchant_id counterparty_upi   status  device_id  \
# 0    9.88              Send         NaN     user6545@upi  Success  dev101488
# 1   76.25           Receive         NaN     user3199@upi  Success  dev107876
# 2   26.44  Merchant Payment   merch1113     user4690@upi  Success  dev100901
# 3   84.43              Send         NaN     user1982@upi  Success  dev105890
# 4   10.33           Receive         NaN     user4914@upi  Success  dev106780
#
# ...

# %%
import mysql.connector

try:
    
    cnx = mysql.connector.connect(
        host="localhost",
        user="root",
        password="9861055588",
        database="upi_trasactions"
    )
    cursor = cnx.cursor()
    print("Successfully connected to the database.")
except mysql.connector.Error as err:
    print(f"Error: {err}")
    cnx = None
    cursor = None
# Out:
# Successfully connected to the database.

# %%
from sqlalchemy import create_engine


try:
    # Create SQLAlchemy engine
    engine = create_engine('mysql+mysqlconnector://root:9861055588@localhost/upi_trasactions')
    
    # Insert data into customer_feedback table
    df.to_sql('customer_feedback_surveys', con=engine, if_exists='replace', index=False)
    
    print("=" * 80)
    print("DATA INSERTION SUCCESSFUL")
    print("=" * 80)
    print(f"\nInserted {len(df)} records into 'customer_feedback_surveys' table")
    print("\nTable: customer_feedback_surveys")
    print(f"Rows inserted: {len(df)}")
    print(f"Columns: {list(df.columns)}")
    
    # Verify insertion
    cursor.execute("SELECT COUNT(*) FROM customer_feedback_surveys")
    count = cursor.fetchone()[0]
    print(f"\nVerification - Total rows in table: {count}")
    
    print("\n" + "=" * 80)
    
except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# ...
# DATA INSERTION SUCCESSFUL
# ...
#
# Inserted 4000 records into 'customer_feedback_surveys' table
#
# Table: customer_feedback_surveys
# Rows inserted: 4000
# Columns: ['feedback_id', 'customer_id', 'date_submitted', 'feedback_text', 'satisfaction_score', 'issue_type', 'resolved']
#
# Verification - Total rows in table: 4000
#
# ...

# %%
from sqlalchemy import create_engine

try:
    # Create SQLAlchemy engine
    engine = create_engine('mysql+mysqlconnector://root:9861055588@localhost/upi_trasactions')
    
    # Insert data into customer_master table
    df1.to_sql('customer_master', con=engine, if_exists='replace', index=False)
    
    print("=" * 80)
    print("DATA INSERTION SUCCESSFUL")
    print("=" * 80)
    print(f"\nInserted {len(df1)} records into 'customer_master' table")
    print("\nTable: customer_master")
    print(f"Rows inserted: {len(df1)}")
    print(f"Columns: {list(df1.columns)}")
    
    # Verify insertion
    cursor.execute("SELECT COUNT(*) FROM customer_master")
    count = cursor.fetchone()[0]
    print(f"\nVerification - Total rows in table: {count}")
    
    print("\n" + "=" * 80)
    
except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# ...
# DATA INSERTION SUCCESSFUL
# ...
#
# Inserted 10000 records into 'customer_master' table
#
# Table: customer_master
# Rows inserted: 10000
# Columns: ['customer_id', 'full_name', 'mobile_number', 'age', 'gender', 'region', 'date_joined', 'is_business_user', 'risk_score', 'date_joined_dt', 'country']
# Error inserting data: 1412 (HY000): Table definition has changed, please retry transaction

# %%
from sqlalchemy import create_engine

try:
    # Create SQLAlchemy engine
    engine = create_engine('mysql+mysqlconnector://root:9861055588@localhost/upi_trasactions')
    
    # Insert data into device_info table
    df2.to_sql('device_info', con=engine, if_exists='replace', index=False)
    
    print("=" * 80)
    print("DATA INSERTION SUCCESSFUL")
    print("=" * 80)
    print(f"\nInserted {len(df2)} records into 'device_info' table")
    print("\nTable: device_info")
    print(f"Rows inserted: {len(df2)}")
    print(f"Columns: {list(df2.columns)}")
    
    # Verify insertion
    cursor.execute("SELECT COUNT(*) FROM device_info")
    count = cursor.fetchone()[0]
    print(f"\nVerification - Total rows in table: {count}")
    
    print("\n" + "=" * 80)
    
except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# ...
# DATA INSERTION SUCCESSFUL
# ...
#
# Inserted 12000 records into 'device_info' table
#
# Table: device_info
# Rows inserted: 12000
# Columns: ['device_id', 'customer_id', 'device_type', 'app_version', 'is_rooted', 'last_active']
# Error inserting data: 1412 (HY000): Table definition has changed, please retry transaction

# %%
try:
    
    engine = create_engine('mysql+mysqlconnector://root:9861055588@localhost/upi_trasactions')
    
    
    df3.to_sql('fraud_alert_history', con=engine, if_exists='replace', index=False)
    
    print("=" * 80)
    print("DATA INSERTION SUCCESSFUL")
    print("=" * 80)
    print(f"\nInserted {len(df3)} records into 'fraud_alert_history' table")
    print("\nTable: fraud_alert_history")
    print(f"Rows inserted: {len(df3)}")
    print(f"Columns: {list(df3.columns)}")
    
    # Verify insertion
    cursor.execute("SELECT COUNT(*) FROM fraud_alert_history")
    count = cursor.fetchone()[0]
    print(f"\nVerification - Total rows in table: {count}")
    
    print("\n" + "=" * 80)
    
except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# ...
# DATA INSERTION SUCCESSFUL
# ...
#
# Inserted 2000 records into 'fraud_alert_history' table
#
# Table: fraud_alert_history
# Rows inserted: 2000
# Columns: ['alert_id', 'transaction_id', 'alert_type', 'alert_date', 'resolved', 'resolution_date', 'remarks']
# Error inserting data: 1412 (HY000): Table definition has changed, please retry transaction

# %%
try:
    # Create SQLAlchemy engine
    engine = create_engine('mysql+mysqlconnector://root:9861055588@localhost/upi_trasactions')
    
    # Insert data into merchant_info table
    df4.to_sql('merchant_info', con=engine, if_exists='replace', index=False)
    
    print("=" * 80)
    print("DATA INSERTION SUCCESSFUL")
    print("=" * 80)
    print(f"\nInserted {len(df4)} records into 'merchant_info' table")
    print("\nTable: merchant_info")
    print(f"Rows inserted: {len(df4)}")
    print(f"Columns: {list(df4.columns)}")
    
    # Verify insertion
    cursor.execute("SELECT COUNT(*) FROM merchant_info")
    count = cursor.fetchone()[0]
    print(f"\nVerification - Total rows in table: {count}")
    
    print("\n" + "=" * 80)
    
except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# ...
# DATA INSERTION SUCCESSFUL
# ...
#
# Inserted 500 records into 'merchant_info' table
#
# Table: merchant_info
# Rows inserted: 500
# Columns: ['merchant_id', 'merchant_name', 'merchant_type', 'region', 'onboard_date', 'risk_score']
# Error inserting data: 1412 (HY000): Table definition has changed, please retry transaction

# %%
try:
    # Create SQLAlchemy engine
    engine = create_engine('mysql+mysqlconnector://root:9861055588@localhost/upi_trasactions')
    
    # Insert data into upi_account_details table
    df5.to_sql('upi_account_details', con=engine, if_exists='replace', index=False)
    
    print("=" * 80)
    print("DATA INSERTION SUCCESSFUL")
    print("=" * 80)
    print(f"\nInserted {len(df5)} records into 'upi_account_details' table")
    print("\nTable: upi_account_details")
    print(f"Rows inserted: {len(df5)}")
    print(f"Columns: {list(df5.columns)}")
    
    # Verify insertion
    cursor.execute("SELECT COUNT(*) FROM upi_account_details")
    count = cursor.fetchone()[0]
    print(f"\nVerification - Total rows in table: {count}")
    
    print("\n" + "=" * 80)
    
except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# ...
# DATA INSERTION SUCCESSFUL
# ...
#
# Inserted 12000 records into 'upi_account_details' table
#
# Table: upi_account_details
# Rows inserted: 12000
# Columns: ['upi_id', 'customer_id', 'bank_name', 'account_type', 'date_added', 'status']
# Error inserting data: 1412 (HY000): Table definition has changed, please retry transaction

# %%
try:
    engine = create_engine('mysql+mysqlconnector://root:9861055588@localhost/upi_trasactions')
    
    
    df6.to_sql('upi_transaction_history', con=engine, if_exists='replace', index=False)
    
    print("=" * 80)
    print("DATA INSERTION SUCCESSFUL")
    print("=" * 80)
    print(f"\nInserted {len(df6)} records into 'upi_transaction_history' table")
    print("\nTable: upi_transaction_history")
    print(f"Rows inserted: {len(df6)}")
    print(f"Columns: {list(df6.columns)}")
    
    
    cursor.execute("SELECT COUNT(*) FROM upi_transaction_history")
    count = cursor.fetchone()[0]
    print(f"\nVerification - Total rows in table: {count}")
    
    print("\n" + "=" * 80)
    
except Exception as e:
    print(f"Error inserting data: {e}")
# Out:
# ...
# DATA INSERTION SUCCESSFUL
# ...
#
# Inserted 100000 records into 'upi_transaction_history' table
#
# Table: upi_transaction_history
# Rows inserted: 100000
# Columns: ['transaction_id', 'upi_id', 'customer_id', 'timestamp', 'amount', 'transaction_type', 'merchant_id', 'counterparty_upi', 'status', 'device_id', 'device_type', 'channel', 'fraud_flag', 'reversal_flag', 'failure_reason']
# Error inserting data: 1412 (HY000): Table definition has changed, please retry transaction

# %%
connections_to_check = ['cnx', 'cursor', 'temp_cnx', 'temp_cursor', 'clean_cnx', 'clean_cursor']

for conn_name in connections_to_check:
    if conn_name in globals():
        conn = globals()[conn_name]
        if conn is not None:
            if 'cursor' in conn_name:
                try:
                    conn.close()
                    print(f"Closed {conn_name}.")
                except:
                    pass
            elif hasattr(conn, 'is_connected') and conn.is_connected():
                try:
                    conn.close()
                    print(f"Closed {conn_name}.")
                except:
                    pass

print("All MySQL connections have been closed.")
# Out:
# Closed cnx.
# Closed cursor.
# All MySQL connections have been closed.
